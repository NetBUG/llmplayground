# %%
# !CUDA_VISIBLE_DEVICES="1" python3 -m torch.distributed.launch --nproc_per_node 2 ./train.py --model="gpt2-large" --fp16='O3'

# %%
import os
import pandas as pd
df = pd.read_csv('messages.csv')

# %%
import random

BST_DATA_DIR = "ParlAI/data/blended_skill_talk/"
MSC_DATA_DIR = "ParlAI/data/msc/msc/msc_dialogue/"
MAX_DIALOG_TOKENS_LEN = 256
def separate_profile_dialog(persona_dialog):
    profile = [u for u in persona_dialog if u.startswith("Bot profile:")]
    dialog = [u for u in persona_dialog if u.startswith("Person:") or u.startswith("Bot:")]

    return profile, dialog


def get_processed_dialog(dialog, bot_label, person_label, profile):
    processed_dialog = []
    for utterance in dialog:
        utterance = utterance.replace(bot_label, "Bot")
        utterance = utterance.replace(person_label, "Person")
        processed_dialog.append(utterance)

    persona = [f"Bot profile: {p}" for p in profile]

    return {"persona": persona, "dialog": processed_dialog}


def prepare_person_bot_dialog(dialog):
    prepared_dialog = []
    user1, user2 = ("Person", "Bot") if random.randint(0, 1) else ("Bot", "Person")
    for i, utterance in enumerate(dialog):
        user = user1 if i % 2 == 0 else user2
        prepared_dialog.append(f"{user}: {utterance}")

    return prepared_dialog

# %%
from datasets import load_dataset
from loguru import logger

def _normalize_dialog(raw_dialog):
    dialog = [d.strip() for d in raw_dialog]

    for ch in "’?!.,":
        dialog = [d.replace(f" {ch}", ch) for d in dialog]

    dialog = [d.replace(".", ". ") for d in dialog]
    dialog = [d.replace("  ", " ") for d in dialog]
    dialog = [d.strip() for d in dialog]

    dialog = [d.replace("’", "'") for d in dialog]
    dialog = [d.replace("' s", "'s") for d in dialog]
    dialog = [d.replace("' ll", "'ll") for d in dialog]
    dialog = [d.replace("' re", "'re") for d in dialog]
    dialog = [d.replace("' t", "'t") for d in dialog]
    dialog = [d.replace("' m", "'m") for d in dialog]

    return dialog


def prepare_daily_dialog():
    daily_dialog = load_dataset("daily_dialog")

    samples = []
    for data_type in daily_dialog:
        for x in daily_dialog[data_type]:
            dialog = _normalize_dialog(x["dialog"])
            prepared_dialog = prepare_person_bot_dialog(dialog)
            samples.append(prepared_dialog)

    logger.info(f"Prepared {len(samples)} dialogs of daily_dialog dataset")

    return samples

# %%
import re
from collections import defaultdict

def _filter_dialogs(dialogs):
    processed_dialogs = []
    for dialog in dialogs:
        has_bad_utterance = False
        for utterance in dialog:
            # for some reason it could be broken records with meta info in utterances. Skip those dialogs
            if "_conv" in utterance:
                has_bad_utterance = True

        if not has_bad_utterance:
            processed_dialogs.append(dialog)

    return processed_dialogs


def prepare_empathetic_dialogues():
    dataset = load_dataset("empathetic_dialogues")
    dialog_id_to_dialog = defaultdict(list)
    for data_type in dataset:
        for sample in dataset[data_type]:
            utterance = sample["utterance"].replace("_comma_", ",").strip()
            utterance = re.sub(" +", " ", utterance)
            dialog_id_to_dialog[sample["conv_id"]].append(utterance)

    dialogs = list(dialog_id_to_dialog.values())
    filtered_dialogs = _filter_dialogs(dialogs)

    prepared_dialogs = [prepare_person_bot_dialog(d) for d in filtered_dialogs]
    logger.info(f"Prepared {len(prepared_dialogs)} dialogs of empathetic_dialogues dataset")

    return prepared_dialogs

# %%
def prepare_bst(data_dir=BST_DATA_DIR):
    samples = []
    for dataset_type in ["train", "test", "valid"]:
        print(os.listdir(data_dir))
        #print(data_dir)
        data_path = os.path.join(data_dir, f"{dataset_type}.json")
        
        with open(data_path, encoding="utf-8") as f:
            data = json.load(f)
            for row in data:
                person0_profile = row["personas"][0]
                person1_profile = row["personas"][1]

                conv_starter = [
                    f"person 0: {row['free_turker_utterance']}",
                    f"person 1: {row['guided_turker_utterance']}",
                ]
                dialog = [f"person {u[0]}: {u[1]}" for u in row["dialog"]]
                full_dialog = conv_starter + dialog

                processed_dialog1 = get_processed_dialog(
                    full_dialog, bot_label="person 0", person_label="person 1", profile=person0_profile
                )
                samples.append(processed_dialog1)

                processed_dialog2 = get_processed_dialog(
                    full_dialog, bot_label="person 1", person_label="person 0", profile=person1_profile
                )
                samples.append(processed_dialog2)

    logger.info(f"Prepared {len(samples)} dialogs of BST dataset")

    return samples

# %%
import json
import jsonlines

def _generate_personalized_dialogs(raw_dialog):
    """
    :param raw_dialog: {'personas': [[str], [str]], dialog: [{'text': str, 'id': str}]}
    :return: list containing two personalized dialogs: first dialog with persona1 facts, second dialog with persona2 facts
    """
    persona_facts_1 = raw_dialog["personas"][0]
    persona_facts_1 = [text.strip() for text in persona_facts_1]

    persona_facts_2 = raw_dialog["personas"][1]
    persona_facts_2 = [text.strip() for text in persona_facts_2]

    dialog = [f"{u['id']}: {u['text'].strip()}" for u in raw_dialog["dialog"]]

    personalized_dialog1 = get_processed_dialog(
        dialog, bot_label="Speaker 1", person_label="Speaker 2", profile=persona_facts_1
    )

    personalized_dialog2 = get_processed_dialog(
        dialog, bot_label="Speaker 2", person_label="Speaker 1", profile=persona_facts_2
    )

    return [personalized_dialog1, personalized_dialog2]


def prepare_msc(sessions_data_dir=MSC_DATA_DIR):
    dialogs = []

    for session_dir in ["session_2", "session_3", "session_4", "session_5"]:
        for dataset_type in ["train", "test", "valid"]:
            data_path = os.path.join(sessions_data_dir, session_dir, f"{dataset_type}.txt")
            
            if not os.path.isfile(data_path):
                continue

            with jsonlines.open(data_path) as reader:
                for raw_dialog in reader:
                    dialogs += _generate_personalized_dialogs(raw_dialog)

    init_dialogs_path = os.path.join(sessions_data_dir, "init_persona_all.json")
    
    print(sessions_data_dir, os.listdir(sessions_data_dir))
    
    with open(init_dialogs_path, encoding="utf-8") as f:
        
        data = json.load(f)
        for key, raw_dialog in data.items():
            if "train" not in key:
                continue

            raw_dialog["dialog"] = [
                {"text": line["text"], "id": f"Speaker {1 + i % 2}"} for i, line in enumerate(raw_dialog["dialog"])
            ]
            dialogs += _generate_personalized_dialogs(raw_dialog)

    logger.info(f"Prepared {len(dialogs)} dialogs of MSC dataset")

    return dialogs

# %%
def prepare_persona_chat():
    dataset = load_dataset("bavard/personachat_truecased")
    samples = []
    for data_type in dataset:
        for sample in dataset[data_type]:
            persona = [f"Bot profile: {p}" for p in sample["personality"]]
            history = sample["history"] + [sample["candidates"][-1]]

            prepared_history = []
            user1, user2 = ("Person", "Bot")
            for i, utterance in enumerate(history):
                user = user1 if i % 2 == 0 else user2
                prepared_history.append(f"{user}: {utterance}")

            dialog = [u for u in prepared_history if "SILENCE" not in u]

            if len(dialog) >= 2:
                samples.append({"persona": persona, "dialog": dialog})

    logger.info(f"Prepared {len(samples)} dialogs of persona_chat dataset")

    return samples

# %%
import random

def separate_profile_dialog(persona_dialog):
    profile = [u for u in persona_dialog if u.startswith("Bot profile:")]
    dialog = [u for u in persona_dialog if u.startswith("Person:") or u.startswith("Bot:")]

    return profile, dialog


def get_processed_dialog(dialog, bot_label, person_label, profile):
    processed_dialog = []
    for utterance in dialog:
        utterance = utterance.replace(bot_label, "Bot")
        utterance = utterance.replace(person_label, "Person")
        processed_dialog.append(utterance)

    persona = [f"Bot profile: {p}" for p in profile]

    return {"persona": persona, "dialog": processed_dialog}


def prepare_person_bot_dialog(dialog):
    prepared_dialog = []
    user1, user2 = ("Person", "Bot") if random.randint(0, 1) else ("Bot", "Person")
    for i, utterance in enumerate(dialog):
        user = user1 if i % 2 == 0 else user2
        prepared_dialog.append(f"{user}: {utterance}")

    return prepared_dialog

# %%
from nltk import ngrams
from tqdm import tqdm

def _encode_dialogs(dialogs, tokenizer):
    sep = tokenizer.eos_token
    dialogs_strs = [sep.join(d) + sep for d in dialogs]
    tokenized_samples = tokenizer.batch_encode_plus(dialogs_strs)

    return tokenized_samples["input_ids"]


def read_personalized_dialogs_splits(tokenizer, max_tokens_len=MAX_DIALOG_TOKENS_LEN):
    personalized_dialogs = prepare_bst() + prepare_msc() + prepare_persona_chat()
    logger.info(f"Personalized dialogs: {len(personalized_dialogs)}")

    dialogs_splits = set()
    for obj in tqdm(personalized_dialogs):
        persona = obj["persona"]
        dialog = obj["dialog"]

        # generate all possible subdialogs and filter them by tokens length
        dialog_splits = []
        for n in range(2, len(dialog) + 1):
            dialog_splits += ngrams(dialog, n)

        dialog_splits = [tuple(persona + list(d)) for d in dialog_splits]
        encoded_dialog_splits = _encode_dialogs(dialog_splits, tokenizer)

        for split, encoded_split in zip(dialog_splits, encoded_dialog_splits):
            if len(encoded_split) > max_tokens_len:
                continue
            dialogs_splits.add(split)

    logger.info(f"Personalized dialogs splits: {len(dialogs_splits)}")

    return list(dialogs_splits)


def filter_personalized_dialogs(dialogs):
    """Leave the longest dialogs with unique dialog prefix."""
    prefix_to_dialog = {}

    for persona_dialog in dialogs:
        profile, dialog = separate_profile_dialog(persona_dialog)
        prefix = tuple(profile + dialog[:2])

        if len(persona_dialog) > len(prefix_to_dialog.get(prefix, [])):
            prefix_to_dialog[prefix] = persona_dialog

    filtered_dialogs = list(prefix_to_dialog.values())
    logger.info(f"Filtered personalized dialogs: {len(filtered_dialogs)}")

    return filtered_dialogs
def _encode_dialog(dialog, tokenizer):
        sep = tokenizer.eos_token
        dialog_str = sep.join(dialog) + sep
        encoded_sample = tokenizer.encode(dialog_str)

        return encoded_sample

# %%
import pickle

import torch
from torch.utils.data import Dataset


class ConversationDataset(Dataset):
    def __init__(self, args, tokenizer, max_tokens_len=MAX_DIALOG_TOKENS_LEN):
        cached_features_file = os.path.join(args.cache_dir, f"cached_features_{max_tokens_len}.pickle")
        if os.path.exists(cached_features_file) and not args.overwrite_cache:
            logger.info(f"Loading features from cached file {cached_features_file}")
            with open(cached_features_file, "rb") as fh:
                self.examples = pickle.load(fh)
        else:
            logger.info(f"Creating features from dataset file at {args.cache_dir}")
            os.makedirs(args.cache_dir, exist_ok=True)

            dialogs = self._read_dialogs(tokenizer, max_tokens_len)

            self.examples = []
            for dialog in tqdm(dialogs):
                if len(dialog) < 2:
                    continue

                encoded_dialog = _encode_dialog(dialog, tokenizer)
                if len(encoded_dialog) <= max_tokens_len:
                    self.examples.append(encoded_dialog)

            logger.info(f"{len(self.examples)} dialogs left after tokenization")

            logger.info(f"Saving features into cached file {cached_features_file}")
            with open(cached_features_file, "wb") as fh:
                pickle.dump(self.examples, fh, protocol=pickle.HIGHEST_PROTOCOL)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, item):
        return torch.tensor(self.examples[item], dtype=torch.long)

    @staticmethod
    def _read_dialogs(tokenizer, max_tokens_len, common_dialogs_weight=5):
        personalized_dialogs_splits = read_personalized_dialogs_splits(tokenizer, max_tokens_len)
        personalized_dialogs = filter_personalized_dialogs(personalized_dialogs_splits)

        common_dialogs = prepare_daily_dialog() + prepare_empathetic_dialogues()
        logger.info(f"Common dialogs: {len(common_dialogs)}")

       

        dialogs = personalized_dialogs + common_dialogs * common_dialogs_weight
        logger.info(f"Total dialogs: {len(dialogs)}")

        random.shuffle(dialogs)

        return dialogs

    @staticmethod
    def _encode_dialog(dialog, tokenizer):
        sep = tokenizer.eos_token
        dialog_str = sep.join(dialog) + sep
        encoded_sample = tokenizer.encode(dialog_str)

        return encoded_sample

# %%
TEST_DATA_PATH = 'test_data.jsonl'
TEST_CANDS_NUM = 5

DEVICE = "cuda:0"
MODEL_DIR = "./"

TOP_P = 0.9
TOP_K = 40
TEMPERATURE = 1
MAX_RESPONSE_LEN = 24

# %%
from apex import amp
import numpy as np
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import DataLoader
from transformers import AdamW, get_linear_schedule_with_warmup
from transformers import GPT2Tokenizer, TrainingArguments, Trainer, GPTNeoForCausalLM
import wandb

wandb.init(project="gpt_neo_training_2021", entity="netbug")

def decode_responses(responses_ids, tokenizer):
    responses_ids = [r for r in responses_ids if r[-1] == tokenizer.eos_token_id]
    responses = [tokenizer.decode(r, skip_special_tokens=True) for r in responses_ids]
    responses = [r.strip() for r in responses if r]

    return responses

def _read_test_contexts(test_data_path='test_data.jsonl'):
    with jsonlines.open(test_data_path) as reader:
        return [dialog for dialog in reader]


def _save_checkpoint(args, model, tokenizer,it):
    output_dir = os.path.join(args.output_dir, f"checkpoint_{it}")
    os.makedirs(output_dir, exist_ok=True)
    logger.info(f"Saving model checkpoint to {output_dir}")

    model.save_pretrained(output_dir)
    tokenizer.save_pretrained(output_dir)
    torch.save(args, os.path.join(output_dir, "training_args.bin"))


def _generate_gpt_candidates(
    context,
    cands_num,
    model,
    tokenizer,
    device,
    top_p=TOP_P,
    top_k=TOP_K,
    temperature=TEMPERATURE,
    max_response_len=MAX_RESPONSE_LEN,
):
    sep = tokenizer.eos_token
    context_str = sep.join(context) + sep
    encoded_context = tokenizer.encode(context_str, return_tensors="pt").to(device)
    context_len = encoded_context.shape[-1]

    responses_ids = model.generate(
        encoded_context,
        do_sample=True,
        max_length=context_len + max_response_len,
        top_p=top_p,
        top_k=top_k,
        temperature=temperature,
       
        num_return_sequences=cands_num,
        pad_token_id=tokenizer.eos_token_id,
        return_dict=True
    )
    responses_ids = [r[context_len:] for r in responses_ids]

    return decode_responses(responses_ids, tokenizer)


def evaluate(args, model, tokenizer, val_dataset, test_contexts=None, cands_num=2):
    def collate(examples):
        return pad_sequence(examples, batch_first=True, padding_value=tokenizer.eos_token_id)

    if test_contexts:
        logger.info(f"Generate candidates for {len(test_contexts)} test contexts")
        for context in test_contexts:
            candidates = _generate_gpt_candidates(context, cands_num, model, tokenizer, args.device)
            for cand in candidates:
                logger.info(f"{context} -> {cand}")

    logger.info(f"*** Running evaluation on {len(val_dataset)} examples, eval batch size = {args.eval_batch_size} ***")

    dataloader = DataLoader(val_dataset, batch_size=args.eval_batch_size, collate_fn=collate, drop_last=True)
    eval_loss = 0.0
    model.eval()

    for inputs in dataloader:
        inputs = inputs.to(args.device)
        with torch.no_grad():
            outputs = model(inputs, labels=inputs,return_dict=True)
        lm_loss = outputs[0]
        eval_loss += lm_loss.mean().item()

    eval_loss = eval_loss / len(dataloader)
    perplexity = torch.exp(torch.tensor(eval_loss))

    logger.info(f"Model perplexity on val dataset = {perplexity}")

    return perplexity


def train(args, train_dataset, val_dataset, model, tokenizer):
    def collate(examples):
        return pad_sequence(examples, batch_first=True, padding_value=tokenizer.eos_token_id)

    train_dataloader = DataLoader(
        train_dataset, shuffle=True, batch_size=args.train_batch_size, collate_fn=collate, drop_last=True
    )
    
    training_steps = args.num_train_epochs * len(train_dataloader) // args.gradient_accumulation_steps

    optimizer = AdamW(params=model.parameters(), 
                      lr=args.learning_rate, eps=args.adam_epsilon)
    
    
    scheduler = get_linear_schedule_with_warmup(
        optimizer, num_warmup_steps=args.warmup_steps, num_training_steps=training_steps
    )
    
    model, optimizer = amp.initialize(model, optimizer, opt_level=args.fp16_opt_level)
    #if args.n_gpu > 1:
    #    model = torch.nn.DataParallel(model).to('cuda')#,device_ids=[0, 1]
   
    #model = torch.nn.DataParallel(model, device_ids=[0, 1])
    
    
    test_contexts = _read_test_contexts()
    #print(test_contexts[0])
    logger.info("***** Running training *****")
    logger.info(f"  Num examples = {len(train_dataset)}")
    logger.info(f"  Num Epochs = {args.num_train_epochs}")
    logger.info(f"  Total train batch size  = {args.train_batch_size * args.gradient_accumulation_steps}")
    logger.info(f"  Gradient Accumulation steps = {args.gradient_accumulation_steps}")
    logger.info(f"  Total optimization steps = {training_steps}")

    best_ppl = np.inf
    backprop_steps = 0
    model.zero_grad()

    for epoch in range(args.num_train_epochs):
        logger.info(f"Epoch {epoch + 1}")
        
        #evaluate(args, model, tokenizer, val_dataset, test_contexts)
       
        epoch_iterator = tqdm(train_dataloader, desc="Iteration")
        for step, inputs in enumerate(epoch_iterator, start=1):
            inputs = inputs.to(args.device)
            model.train()
            outputs = model(inputs, labels=inputs)
            #print(outputs)
            loss = outputs['loss']
            
           
            
            #print(loss)
            if args.n_gpu > 1:
                loss = loss.mean()
                
            if args.gradient_accumulation_steps > 1:
                loss = loss / args.gradient_accumulation_steps
            
            
            with amp.scale_loss(loss, optimizer) as scaled_loss:
                scaled_loss.backward()
                
            #if step % args.eval_steps == 0:
             #       _save_checkpoint(args, model, tokenizer)
              #      logger.info("Saved")
                    
            if step % args.gradient_accumulation_steps == 0:
                logger.info("loss = {}".format(loss))
                wandb.log({"loss":  loss.item()})
                torch.nn.utils.clip_grad_norm_(amp.master_params(optimizer), args.max_grad_norm)
                
                optimizer.step()
                
                scheduler.step()
                model.zero_grad()

                backprop_steps += 1
                if step % args.eval_steps == 0:
                    _save_checkpoint(args, model, tokenizer,it=step)
                    logger.info(f"Saved at step {step}")
                    
                    #ppl = evaluate(args, model, tokenizer, val_dataset, test_contexts)
                    #strange bug produced
                    #wandb.log({"ppl":  ppl})
                    #if ppl < best_ppl:
                     #   logger.info("Best model found")
                      #  best_ppl = ppl
                        
                       # _save_checkpoint(args, model, tokenizer,it=f'best_on_{step}')

    return model

# %%
import numpy as np
import torch
from loguru import logger
from sklearn.model_selection import train_test_split
from transformers import GPT2TokenizerFast
from transformers import OpenAIGPTLMHeadModel, OpenAIGPTTokenizer, GPT2LMHeadModel, GPT2Tokenizer

class Args:
    def __init__(self):
        self.overwrite_cache = False
        self.tokenizer_name = "EleutherAI/gpt-neo-1.3B"
        self.model_name_or_path = 'EleutherAI/gpt-neo-1.3B'
        self.output_dir = "ssd/models_gpt/model_dir_xl_512"
        self.cache_dir = "cache_dir"
        self.eval_batch_size = 1
        self.train_batch_size = 1
        self.gradient_accumulation_steps = 1
        self.learning_rate = 5e-5
        self.warmup_steps = 0
        self.adam_epsilon = 1e-8
        self.max_grad_norm = 1.0
        self.num_train_epochs = 1
        self.eval_steps = 10000
        self.seed = 42
        self.fp16 = True
        self.fp16_opt_level = "O1"
        self.n_gpu = 0
        self.local_rank = 2
        self.device = torch.device(DEVICE)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

def freeze(
    model,
    freeze_emb=True,
    freeze_ln=False,
    freeze_attn=False,
    freeze_ff=True,
    freeze_other=True,
):
    
    for name, p in model.named_parameters():
    # freezing all parameters except the layernorm and positional embeddings

        name = name.lower()
        if 'ln' in name or 'norm' in name:
            p.requires_grad = not freeze_ln
        elif 'embeddings' in name:
            p.requires_grad = not freeze_emb
        elif 'mlp' in name:
            p.requires_grad = not freeze_ff
        elif 'attn' in name:
            p.requires_grad = not freeze_attn
        else:
            p.requires_grad = not freeze_other
           
    return model

def main():
    args = Args()
    
    args.device = torch.device(DEVICE)

    logger.info(f"Training/evaluation parameters {vars(args)}")
    set_seed(args.seed)

    if args.model_name_or_path.startswith('EleutherAI'):
        tokenizer = GPT2Tokenizer.from_pretrained(args.tokenizer_name, bos_token='<|endoftext|>',
                                              eos_token='<|endoftext|>', pad_token='<|pad|>')
        
        model = GPTNeoForCausalLM.from_pretrained(args.model_name_or_path,return_dict=True).to(args.device)
        model = freeze(model)
        
        
    else:
        tokenizer = GPT2Tokenizer.from_pretrained(args.tokenizer_name)
   
        model = GPT2LMHeadModel.from_pretrained(args.model_name_or_path).to(args.device)
    #model.to(args.device)

    dataset = ConversationDataset(args, tokenizer)
    #print(dataset.)
    train_dataset, val_dataset = train_test_split(dataset, test_size=500, random_state=42, shuffle=True)
    logger.info(f"Train dataset = {len(train_dataset)} samples; Val dataset = {len(val_dataset)} samples")

    model = train(args, train_dataset, val_dataset, model, tokenizer)

    evaluate(args, model, tokenizer, val_dataset)

# %%
if __name__ == "__main__":
    main()

# %%
model = GPTNeoForCausalLM.from_pretrained(args.model_name_or_path).to(args.device)

# %%
torch.cuda.empty_cache()

# %%
args = Args()

# %%
import torch.distributed.autograd as dist_autograd
from torch.nn.parallel import DistributedDataParallel as DDP
from torch import optim
from torch.distributed.optim import DistributedOptimizer
from torch.distributed.rpc import RRef

# %%
tokenizer = GPT2Tokenizer.from_pretrained(args.tokenizer_name)
model = GPTNeoForCausalLM.from_pretrained(args.model_name_or_path)
model = DDP(model, device_ids=2).to('cuda')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13226/1408622970.py in <module>
#       1 tokenizer = GPT2Tokenizer.from_pretrained(args.tokenizer_name)
#       2 model = GPTNeoForCausalLM.from_pretrained(args.model_name_or_path)
# ----> 3 model = DDP(model, device_ids=2).to('cuda')
#
# ~/.local/lib/python3.8/site-packages/torch/nn/parallel/distributed.py in __init__(self, module, device_ids, output_device, dim, broadcast_buffers, process_group, bucket_cap_mb, find_unused_parameters, check_reduction, gradient_as_bucket_view)
#     396         )
#     397
# --> 398         if device_ids is not None and len(device_ids) > 1:
#     399             raise ValueError("device_ids can only be None or contain a single element.")
#     400
#
# TypeError: object of type 'int' has no len()

# %%
import random
import json
import numpy as np
from nltk import ngrams
import torch
from loguru import logger
from sklearn.model_selection import train_test_split
from transformers import GPT2TokenizerFast
from transformers import OpenAIGPTLMHeadModel, OpenAIGPTTokenizer, GPT2LMHeadModel, GPT2Tokenizer
class Args:
    def __init__(self):
        self.overwrite_cache = False
        self.tokenizer_name = ""
        self.model_name_or_path = "microsoft/DialoGPT-large"
        self.output_dir = "model_dir1"
        self.cache_dir = "cache_dir"
        self.eval_batch_size = 2
        self.train_batch_size = 2
        self.gradient_accumulation_steps = 32
        self.learning_rate = 5e-5
        self.warmup_steps = 0
        self.adam_epsilon = 1e-8
        self.max_grad_norm = 1.0
        self.num_train_epochs = 1
        self.eval_steps = 10000
        self.seed = 42
        self.fp16 = True
        self.fp16_opt_level = "O3"
args = Args()

MODEL_DIR = '/mnt/swamp/models/GPTNeo_ckpt20'

tokenizer = GPT2Tokenizer.from_pretrained(MODEL_DIR)
model = GPT2LMHeadModel.from_pretrained(args.tokenizer_name)
model.to('cuda')

TOP_P = 0.9
TOP_K = 40
TEMPERATURE = 1
MAX_RESPONSE_LEN = 24

def decode_responses(responses_ids, tokenizer):
    responses_ids = [r for r in responses_ids if r[-1] == tokenizer.eos_token_id]
    responses = [tokenizer.decode(r, skip_special_tokens=True) for r in responses_ids]
    
    responses = [r.strip() for r in responses if r]

    return responses


def generate_gpt_candidates(
    context,
    cands_num,
    model,
    tokenizer,
    device='cuda',
    top_p=TOP_P,
    top_k=TOP_K,
    temperature=TEMPERATURE,
    max_response_len=MAX_RESPONSE_LEN,
):
    sep = tokenizer.eos_token
    context_str = sep.join(context) + sep
    
    encoded_context = tokenizer.encode(context_str, return_tensors="pt").to(device)
    context_len = encoded_context.shape[-1]

    responses_ids = model.generate(
        encoded_context,
        do_sample=True,
        max_length=context_len + max_response_len,
        top_p=top_p,
        top_k=top_k,
        temperature=temperature,
        num_return_sequences=cands_num,
        pad_token_id=tokenizer.eos_token_id,
    )
    resp = []
    for response in responses_ids:
        
        r = tokenizer.decode(response).replace(context_str,'')
        
        if r.split(tokenizer.eos_token)[0]:
            resp+=[r.split(tokenizer.eos_token)[0]]
        else:
            resp+=[r]
        
    #esponses_ids = [r[context_len:] for r in responses_ids]

    return resp#decode_responses(responses_ids, tokenizer)

generate_gpt_candidates(
    context=['Bot profile: I dont play video games.  I like to walk on the beach. I like pop music.',
             'Hi',
             'Hi',
             'Hi :DhiHi there Hey, how are you? I am great and you are awesome',
             'What are you Doing?'],model=model,tokenizer=tokenizer,cands_num=4)
# Out:
# ['Oh I am doing great thanks for asking',
#  'Well I am just relaxing and enjoying life :D',
#  'I am eating and going to my class.Im good!',
#  'I wanna play GTA V and I wanna play it, you know I play GTA V on my phone...']

# %%
generate_gpt_candidates(context=['Bot profile: I dont play video games.  I like to walk on the beach. I like pop music.','Hi','Hi','Hi thereHey, how are you? I am great and you are awesome','What are you Doing?','Haha, its my first day. Just got a new phone.','Oh wow what is model','LG G3.','Oh thats good, i have an iphone', 'Oh you are a lucky one!','Thats right','What is your name?','jhb? Thats strange name'],model=model,tokenizer=tokenizer,cands_num=10)
# Out:
# ['I want to give you a pokemon.',
#  'Lol i thought soo',
#  'Yea its a great name',
#  'Haha its like my last name, but not really',
#  'oh right it is',
#  'jhb?',
#  "Lol it's the same for you.",
#  "Jhb? I have an a a a, but that's",
#  'haha thats a weird name',
#  'He has a good one.j']

# %%
# !nvidia-smi
# Out:
# Wed Sep 29 08:51:08 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0 Off |                  N/A |
# |  0%   46C    P8    16W / 350W |  21789MiB / 24265MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA GeForce ...  Off  | 00000000:06:00.0 Off |                  N/A |
# |  0%   37C    P8    22W / 350W |  13361MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     38754      C   /usr/bin/python3                21787MiB |
# |    1   N/A  N/A     38754      C   /usr/bin/python3                13359MiB |
# +-----------------------------------------------------------------------------+

# %%
dataset = ConversationDataset(args, tokenizer)
# Out:
# 2021-09-28 13:43:23.226 | INFO     | __main__:__init__:15 - Loading features from cached file cache_dir/cached_features_256.pickle
#   0%|▏                                   | 700/177926 [00:30<1:09:02, 42.78it/s]

# %%
train_dataset, val_dataset = train_test_split(dataset, test_size=500, random_state=42, shuffle=True)

# %%
import json

with open('output.jsonl', 'w') as outfile:
    for entry in JSON_file:
        json.dump(entry, outfile)

# %%
tokenizer.decode(dataset.examples[0])
# Out:
# "Bot profile: I don't play video games.  I like to walk on the beach. I like pop music.<|endoftext|>Bot profile: I like to watch TV.  I like Game of Thrones. My favorite season of Game of Thrones is season five. I like watching new shows. I have not watched Bridgerton.<|endoftext|>Bot profile: I eat meat.<|endoftext|>Bot profile: I live in an area near a beach.<|endoftext|>Bot: Oh I understand.. I can do that sometimes too. I try to watch new shows that are coming out so I can't go online and read the spoilers.. or accidentally come across them.<|endoftext|>Person: Yep, the exact same thing happens to me. I always end up online or on a forum.<|endoftext|>Bot: It's way too tempting. I do like going online and reading people's opinions afterwards.. but even Game of Thrones season 8 was spoiled online before it was released to the public.<|endoftext|>"

# %%
_read_test_contexts()
# Out:
# ["Bot profile: I've been acting since I was ten years old.<|endoftext|>Bot profile: Now I'm a fixture on a weekly telenovela.<|endoftext|>Bot profile: I'm an actor.<|endoftext|>Bot profile: I made my first movie when I was 18.<|endoftext|>Bot profile: I starred in television commercials when I was young.<|endoftext|>Bot: Just completed another movie. I been acting since age ten.<|endoftext|>Person: I'm close to the beach so I surf a lot.<|endoftext|>Bot: I'm close to the kitchen so I eat a lot.<|endoftext|>Person: Nice, do you make a lot of money acting?<|endoftext|>Bot: No but you'd be a good voiceover artist. Ever tried it?<|endoftext|>Person: No, I work as a life guard.<|endoftext|>Bot: Sorry abut that. I did commercials when I was younger.<|endoftext|>Person: I'm watching the sun go down, it is so beautiful.<|endoftext|>Bot: Oh okay. How many fingers am I holding up?<|endoftext|>Person: That is a hard one two, for the peace sign.<|endoftext|>Bot: I appear on a weekly internet show? You?<|endoftext|>Person: Like on you tube or something?<|endoftext|>Bot: Exactly like Youtube or something.<|endoftext|>",
#  "Bot profile: I can speak French.<|endoftext|>Bot profile: I am from North America. I leanred French in 9th grade. I am at least 30 years old.<|endoftext|>Bot profile: I own an online clothing shop. I work from home.<|endoftext|>Bot: Www. Cafepress. Com lelesfashionshop1 if you want to check it out<|endoftext|>Person: Thanks! I like hiking on weekends. What music do you like?<|endoftext|>Bot: Thank you. In my spare time I go bike riding with my family and write poetry<|endoftext|>Person: That's nice! I like jazz music and play the piano in a band, which I enjoy<|endoftext|>Bot: I like rap, r b, jazz, and reggae music<|endoftext|>Person: Nice! Do you have any pets?<|endoftext|>Bot: No. But I used to have a feist dog that doesn't grow anymore<|endoftext|>",
#  'Bot: i have a box of baby stuff from my twins that i have kept since they have been babies. they are 25 now<|endoftext|>Person: thats very cute to do that<|endoftext|>Bot: it always reminds me of when they were little<|endoftext|>Person: yea i bet it does<|endoftext|>',
#  "Bot profile: I am married to a doctor.<|endoftext|>Bot profile: My family is continuously growing.<|endoftext|>Bot profile: I am a professional tennis player.<|endoftext|>Bot profile: I live in a three storey house.<|endoftext|>Person: Lol. I'd have trouble naming all of them.<|endoftext|>Bot: I cannot even keep them straight half the time.<|endoftext|>",
#  "Person: my mother got a big cake and left it in the fridge for us to eat later, i selfishly took it all upstairs and closed my door and ate all of it while watching anime<|endoftext|>Bot: Oh wow, the whole cake? Has she found out yet? Was she mad?<|endoftext|>Person: she hasn't yet, we're suppose to have it later tonight, but how disappointed she'll be when she comes back from work and sees that the cake has been entirely devoured by me...<|endoftext|>Bot: If you can and have time, I'd try to get a quick replacement and explain to her. Maybe she'll understand.<|endoftext|>",
#  "Bot profile: i live near the ocean.<|endoftext|>Bot profile: i love to surf.<|endoftext|>Person: Oh cool. I've thought about joining my school's swim team, but am too nervous to try. Definitely wouldn't be in the ocean!<|endoftext|>Bot: have you swam before?<|endoftext|>Person: Yes. I do enjoy swimming during the summer months to cool off, but don't think I would do well competitively.<|endoftext|>Bot: practice can always help. but i'm sure competition might be intimidated.<|endoftext|>Person: Maybe I'll give it a go next year. I am quite busy with marching band practice at times.<|endoftext|>Bot: Oh, cool! I did marching percussion in high school. It's more challenging because you have to move while playing!<|endoftext|>",
#  'Person: I took an important test last week.<|endoftext|>Bot: I hope you did well. Was it difficult?<|endoftext|>Person: Yes, but I am sure I did good.<|endoftext|>Bot: What was the test over?<|endoftext|>',
#  "Bot profile: my parents are lawyers.<|endoftext|>Bot profile: i don't like wearing a swimsuit.<|endoftext|>Person: many people believe that the palmistry is a pseudoscience and they also attach religious beliefs over it<|endoftext|>Bot: Ah, I understand now. How has you day been?<|endoftext|>Person: It has been good so far for as Friday. How are you?<|endoftext|>Bot: I've been good just a little tired. What do you like to do on weekends?<|endoftext|>Person: I like to eat out with my family.  My favorite food is shrimp.<|endoftext|>Bot: Ooh, I love shrimp! With cocktail sauce it's so good.<|endoftext|>Person: A lot of people that live in new orleans love shrimp.  Do you have a recipe?<|endoftext|>Bot: I'm a terrible cook. I usually just follow the instructions on the box when I make something. Do you cook at all?<|endoftext|>Person: Yes I do.  I'm pretty good at it but I don't like to cook that much.<|endoftext|>Bot: Is shrimp your favorite thing to cook?<|endoftext|>Person: It is because I like to eat it.  We usually eat out though.<|endoftext|>Bot: Yeah I love eating out. It's just so expensive.<|endoftext|>",
#  "Bot profile: My name is Jim.<|endoftext|>Bot profile: I don't watch sports on a regular basis. I like to do things myself  rather than watching others.<|endoftext|>Bot profile: I am not a fan of the Washington Nationals.<|endoftext|>Bot profile: I like all kinds of music. I like Steely Dan.<|endoftext|>Person: Yeah, I've been watching other sports.  I play hockey whenever I get the chance.<|endoftext|>Bot: Oh, I've never really played hockey but it looks fun. How do I get into hockey? Where I'm from the weather is probably too warm.<|endoftext|>Person: The first thing is you have to learn to skate.  It helps if you have a few soft layers for protection and since it's cold on the ice.  Where are you from?<|endoftext|>Bot: I am from Florida! I don't even know if we have ice skating rinks here lol. How about you? Somewhere colder I assume?<|endoftext|>Person: I live in Philidelphia.  I have orange hair.<|endoftext|>Bot: How is Philadelphia? I heard it's a very historic place and has lots of good food too. Orange hair sounds very unique!<|endoftext|>",
#  "Bot profile: I am 18 years old. I just graduated.<|endoftext|>Bot profile: My mom is also a nurse.<|endoftext|>Bot profile: I am on the road for a long time.<|endoftext|>Bot profile: I have visited Ireland. My favorite landscape is the Irish coastline. I would like to visit Ireland again. I think traveling throughout Europe would be cool.<|endoftext|>Bot profile: I took a road trip to Niagara. I pick up hitchhikers. I picked up a guy in a band on his way to New York City. I'm still friends with my hitchhiker. I like taking road trips. I would never hitchhike as I believe it's too dangerous.<|endoftext|>Bot profile: I like the lights and fast pace of New York but believe it's also dangerous in places.<|endoftext|>Bot profile: I plan on taking a trip to Ireland in the next 5 years.<|endoftext|>Bot: My hitchhiking-rock-band-playing friend texted me last night. You wouldn't believe what he said!<|endoftext|>Person: What did he have to say?<|endoftext|>Bot: He said that he got picked up by Corey Taylor of Slipknot, and they wanted to give him an audition for the band! What are the odds of that.<|endoftext|>",
#  'Person: There was this one time when my family was on a roadtrip and we got lost in the middle of no where at night.<|endoftext|>Bot: That should have been scary?<|endoftext|>Person: Yeah, it was pretty frightening. But we eventually found a small city.<|endoftext|>Bot: Nice. How did you find the city?<|endoftext|>Person: We just tried to follow an intersate highway until we found something. We felt pretty lucky when we did.<|endoftext|>',
#  'Person: We had talked on phone a night before<|endoftext|>Bot: Oh yeah? What about?<|endoftext|>Person: The news of the demise of a bossom friend I mean<|endoftext|>Bot: Oh no, that is sad news indeed. I am sorry to hear that.<|endoftext|>',
#  "Person: Darling, I have news for you. Bobby and his wife, Evelyn, are going to have a baby soon.<|endoftext|>Bot: Really? I thought his wife couldn't have a baby.<|endoftext|>Person: Actually they're expecting the baby to come on my birthday.<|endoftext|>Bot: Oh, what a coincidence! I bet Bobby must be very happy about it. He likes children and always wants a child of his own.<|endoftext|>Person: In fact, they're both very excited about the coming baby. Evelyn imagines what their baby would be look like, since one parent is American and the other one is Chinese.<|endoftext|>Bot: Oh, right. Now I know why they would want to see our boy. It's hard to imagine the wonder! Are they expecting a boy or a girl?<|endoftext|>Person: It's still a mystery. Because Evelyn is only three-month pregnant. But she begins to take her maternity leave now.<|endoftext|>Bot: Oh! You mean she doesn't have to work now? It's hard for young parents not to overreact, isn't it?<|endoftext|>",
#  "Bot profile: I am married.<|endoftext|>Bot profile: I love to read.<|endoftext|>Bot profile: Teaching is my passion.<|endoftext|>Bot profile: My favorite place is the beach.<|endoftext|>Bot: I am a teacher. I am quite passionate about it. What about you?<|endoftext|>Person: I'm a freelancer. Last week I cleaned gutters for money.<|endoftext|>Bot: Do you enjoy doing that type of work?<|endoftext|>Person: No but it allows me to do the things I do enjoy, like archery.<|endoftext|>Bot: I understand. Where do you go to enjoy archery?<|endoftext|>Person: The woods and there is an archery center near my house.<|endoftext|>Bot: That's great. Do you live alone or are you happily married?<|endoftext|>Person: I am happily engaged. How do you get around? I drive a motorcycle.<|endoftext|>Bot: I want to buy a new car but my husband is being a stiff.<|endoftext|>Person: You should get a bike too. But don't get a harley.<|endoftext|>Bot: Why not a harley? What about an indian bike?<|endoftext|>Person: I'm not sure what you mean by indian bike.<|endoftext|>",
#  "Bot profile: I have a dog named Bentley. My dog is a 7-year-old boxer. My dog doesn't like chocolate.<|endoftext|>Bot profile: I like to take baths to relax.<|endoftext|>Bot profile: I have a brother. He needs a job.<|endoftext|>Bot profile: I have not hiked in a while.<|endoftext|>Person: It's like medical lab. Like testing the blood sample.<|endoftext|>Bot: Wow that is really cool. I assume you had to go to college for that right?<|endoftext|>Person: Yes you are right. Sometimes we have a lot assignment when completing the test. That's are very difficult.<|endoftext|>Bot: I had to go to college for my job as well. I graduated with a computer science degree.<|endoftext|>Person: Oh nice to hear. I have to go for work. I will catch you after sometime.<|endoftext|>Bot: Sounds good. It was great speaking to you.<|endoftext|>",
#  "Bot profile: i love cats.<|endoftext|>Bot profile: i play a lot of video games.<|endoftext|>Bot: I enjoy trying food that is out of my comfort zone, like raw fish. Do you like to be daring?<|endoftext|>Person: Only once in a while with food. I am much more daring with my style. Do you like fashion?<|endoftext|>Bot: i like sunglasses and shoes if i can afford them if i'm not spending it all on games<|endoftext|>Person: Those look very nice! I think sunglasses can really add to your style. Do you buy name brand?<|endoftext|>",
#  "Bot profile: I like to watch anime. I watch kakegurai. I am a big fan of comics.<|endoftext|>Bot profile: I only love music bands, have a full wardrobe with the band tees. I like linkin park.<|endoftext|>Bot profile: I work on building drones. I work online. I am not a waitress. I make less money than my boyfriend.<|endoftext|>Bot profile: I live with my boyfriend in an apartment.<|endoftext|>Bot: Yes that is my favorite! It's not for everybody, so I understand! What new songs did you hear this weekend?<|endoftext|>Person: I can't remember the names of them at all which is really annoying because I enjoyed them so much. I know one of them was a French song but that's all I can remember<|endoftext|>Bot: That happens to me all the time! I hope you are taking care of yourself. Working two jobs can be stressful and overwhelming.<|endoftext|>Person: Thanks for asking but yeah I'm doing okay very busy especially with the estate agent job, but I like to be busy gives me something to do haha, How about yourself? Everything okay with you?<|endoftext|>",
#  "Bot profile: I am a yoga instructor.<|endoftext|>Bot profile: I've graduated high school.<|endoftext|>Bot profile: I like the color pink.<|endoftext|>Bot profile: I like being alone.<|endoftext|>Bot profile: My mother is dead.<|endoftext|>Bot profile: I will visit Vegas real soon.<|endoftext|>Bot profile: I wear kilts.<|endoftext|>Person: Cemeteries are cool, you should come to my music store.<|endoftext|>Bot: I will get a ticket to vegas as soon as I get home. Sounds awesome.<|endoftext|>Person: I have played in my band for 17 years, I can get you backstage.<|endoftext|>Bot: I'm totally in! I'll wear my favorite pink kilt. Is that okay?<|endoftext|>Person: Sure, my parents will love it!<|endoftext|>",
#  'Bot: neighbor cat is nasty<|endoftext|>Person: Thaqt is too bad. I like cats, but not the mean ones, only the sweet ones. What does the cat do that is so bad?<|endoftext|>Bot: not this one<|endoftext|>Person: Yeah, I wonder what has made it so mean.<|endoftext|>',
#  "Bot profile: I work as a doctor's assistant.<|endoftext|>Bot profile: I like to fish in the ocean.<|endoftext|>Bot profile: I have a condo at the beach. I like Sublime.<|endoftext|>Bot profile: I am single/unmarried. I have a dog named Scruff.<|endoftext|>Bot profile: I don't have a relationship with my parents. I ran away.<|endoftext|>Bot profile: I like eating fish. I go fishing. I want to buy some new fishing gear.  I want to take a fishing trip to catch big tuna.<|endoftext|>Bot profile: I like to grill. Tuna is not my favorite fish to eat. I like fishing for sport.<|endoftext|>Bot profile: I have weekends off.  I go fishing at least once a month in the summer.<|endoftext|>Bot: That sounds awesome.  What is your longest have you run? Do you plan on running 5K or 10K in the future?<|endoftext|>Person: I have training for 5K. I am so close at the moment. Hoping to get there by next month for when the coach comes to see if I could get a scholarship.<|endoftext|>",
#  "Bot profile: I will visit Canada this fall.<|endoftext|>Bot profile: I don't eat meat.<|endoftext|>Bot profile: I have anxiety attacks.<|endoftext|>Bot profile: I have four cats.<|endoftext|>Bot: Yes, that would be cool. I'm hell bent on visiting Vancouver this year, but I'll wait until the fall I think. Maybe hit some of the more rural areas as well with the foliage.<|endoftext|>Person: oh you should, it's georgeous that time of year too. But of course i think everywhere is nice in the Fall to be honest. I hope your cat makes a speedy recovery.<|endoftext|>Bot: I'm sure she'll be fine. Honestly, it's the bills that worry me. When you visit, there's a hot new steakhouse nearby that also has veggie meals for me. I can take you there.<|endoftext|>Person: Ohhh man i forgot you were vegetarian, im so jealous, its such a nice thing to do for the world but i just love steak too much!!!! Well hey if you need any help you know i always got you covered on the bills.<|endoftext|>",
#  "Bot profile: I am an excellent baker.<|endoftext|>Bot profile: I went to law school.<|endoftext|>Bot profile: Everyone says my pecan pie is the best they have ever had.<|endoftext|>Bot profile: My landlord is raising my rent.<|endoftext|>Bot profile: I was born on Christmas day.<|endoftext|>Bot: Great choice. What do you do for a living?<|endoftext|>Person: I use my computer to work from home.<|endoftext|>Bot: I'm a lawyer. Sometimes I work from home too.<|endoftext|>Person: What is your favorite food?<|endoftext|>Bot: I love fried chicken! How about you?<|endoftext|>",
#  "Bot profile: I love being with the marching band in fall.<|endoftext|>Bot profile: I am in high school. I have a lot of homework. I like band. I am a girl.<|endoftext|>Bot profile: I don't work. I am busy with concert band and marching band.<|endoftext|>Bot profile: I have teachers for parents. I love English class.<|endoftext|>Bot: That's great. I would love to study with them and gain from their knowledge. Is this ok with you?<|endoftext|>Person: of course! they love to do study groups!<|endoftext|>",
#  "Bot profile: I don't have children.<|endoftext|>Bot profile: I go to the pool every thursday for three hours.<|endoftext|>Bot profile: I work five days a week.<|endoftext|>Bot profile: I enjoy shopping.<|endoftext|>Bot profile: I do yoga on tuesdays.<|endoftext|>Person: Awe I am sorry whats wrong with your mom?<|endoftext|>Bot: Oh, she has cancer, but she's getting better!<|endoftext|>",
#  "Bot profile: I work.<|endoftext|>Bot profile: I have few friends.<|endoftext|>Bot: Well its good to be passionate about stuff, I guess<|endoftext|>Person: Oh of course, I love swimming too, pool days are like 3 hrs. What about you?<|endoftext|>Bot: No I don't really swim. Or yoga. I mostly just go to work and come home.<|endoftext|>Person: Sounds like your friends need to take you shopping, dear.<|endoftext|>Bot: Eh I don't really have many friends<|endoftext|>Person: No one to shop or do yoga with? Why on earth not?<|endoftext|>Bot: I guess I'm just not into doing things. Never been close with anyone.<|endoftext|>",
#  "Bot profile: I work out every other day.<|endoftext|>Bot profile: I make cauliflower nachos.<|endoftext|>Bot profile: I like to fly kites during the Fall season.<|endoftext|>Bot profile: I love rugby and other sports. I play rugby game once a week.  I don't play rugby competitively. I am a boy.<|endoftext|>Bot profile: I play basketball.<|endoftext|>Bot profile: I am active. I don't like staying in one place.<|endoftext|>Person: That's what I thought, will this place have big enough portions for you?  I know you want somewhere vegan for my sake, but there's lot of food I can eat at any restaurant.<|endoftext|>Bot: No problem!  We always go to this place because it is so close and the food is really good.  They do sell typical bar food, but they have healthy plates and vegan plates, as well.<|endoftext|>Person: Okay cool! I just wanted to make sure it was really okay with you and you weren't just trying to please me.  How long will the game last?  I'm thinking maybe I can take a walk during it if I get bored, haha.<|endoftext|>",
#  "Bot profile: I am 22.<|endoftext|>Bot profile: I have no kids.<|endoftext|>Bot profile: I work with kids in school.<|endoftext|>Bot profile: I live close to work.<|endoftext|>Bot: There are several things I enjoy. I like simple things, like just a walk in the park, but I also love to plan extravagant vacations. I play poker so I like to visit places with casinos.<|endoftext|>Person: How long have you been playing poker for? My wife and I vacation often, but we usually travel locally. Where do you normally vacation?<|endoftext|>Bot: I have been playing poker since I was young. I used to play with my parents for pennies, lol! I love Las Vegas, but have also been to casinos in Tunica, Mississippi. A casino is not necessarily a prerequisite, I also love anywhere with a coast.<|endoftext|>Person: That's funny I often play cards with my nieces and nephews for pennies. It's a lot of fun with quite a few laughs. I enjoy anywhere with a coast as well, love to beachcomb. Las Vegas seems so overwhelming with all the activity.<|endoftext|>",
#  "Bot profile: I am 77 years old.<|endoftext|>Bot profile: My favorite hobby is gardening.<|endoftext|>Bot profile: My family gets together every saturday.<|endoftext|>Bot profile: My husband died last year.<|endoftext|>Person: Hi. just finished cleaning my house. It is a great feeling. You?<|endoftext|>Bot: I wish I had the energy to do all of that. I am getting old.<|endoftext|>Person: What do you like to do? Reading is a favorite of mine.<|endoftext|>Bot: When I have the energy, I love to garden.<|endoftext|>Person: I would too, but I'm afraid. I never leave home.<|endoftext|>Bot: Wow that must be tough. Why is that?<|endoftext|>Person: My uncle. He kidnapped me when I was a kid.<|endoftext|>Bot: Oh my gosh! That is so terrible. I'm so sorry.<|endoftext|>Person: Thanks. My sisters are the best. They live with me and help me.<|endoftext|>Bot: That's really great. I live alone. My husband passed away last year.<|endoftext|>Person: I am so sorry to hear that.<|endoftext|>Bot: It is okay. My family helps me.<|endoftext|>",
#  "Bot profile: she taught me to cook.<|endoftext|>Bot profile: my mother is from russia.<|endoftext|>Person: That's funny.  Russian seems like a difficult language to learn.<|endoftext|>Bot: Yes.  I tried, but found Spanish much easier.  Imagine learning Chinese or Japanese.  They seem very hard.<|endoftext|>Person: I think those are probably the hardest languages to learn.  Can you speak Spanish fluently now?<|endoftext|>Bot: Not anymore.  I was pretty fluent at one time, back in college, but never was really able to continue using it conversationally.<|endoftext|>Person: I mistakenly took Latin.  It didn't prove to be as useful as I thought.<|endoftext|>Bot: Were you training to be a doctor?  Or lawyer?<|endoftext|>Person: I thought about med school but decided to go into philosophy instead.<|endoftext|>Bot: I studied sociology and psychology.<|endoftext|>",
#  "Bot profile: I just bought a new iphone.<|endoftext|>Bot profile: I travel often. I'm retired.<|endoftext|>Bot profile: I have been to Spain.<|endoftext|>Bot profile: My favorite color is red.<|endoftext|>Bot profile: I have greenish brown eyes.<|endoftext|>Bot profile: I love Chinese and Mexican food.<|endoftext|>Bot profile: I don't like food that is too spicy.<|endoftext|>Person: Could be. I definitely couldn't give it up. I got a tortilla press for my birthday, lol. What's your favorite thing to get when you have Mexican?<|endoftext|>Bot: wow that's amazing. i hope it works fine. i like gaucamole the most. so did you tell the restaurant about their food?<|endoftext|>Person: No, honestly it probably wasn't the food or a problem with the restaurant. It was probably just eating too much and then being stuffed in the car. No one else in my family felt sick after or anything.<|endoftext|>Bot: okay because i think if food makes you sick the restaurant needs to be aware so they don't hurt other people<|endoftext|>",
#  "Bot profile: I like to hike and spend time outdoors.<|endoftext|>Bot profile: My favorite thing to eat is a burrito.<|endoftext|>Bot profile: I love to binge watch shows on streaming services.<|endoftext|>Bot profile: I am close to my mother, but not to my father.<|endoftext|>Bot profile: I'm a guy that enjoys being a guy.<|endoftext|>Person: I'm a netflix junkie! What about you?<|endoftext|>Bot: I love all streaming services, but I really don't get along with my father.<|endoftext|>Person: That's awful. I run with my dad every morning at 4am.<|endoftext|>Bot: I love doing that with my mom.<|endoftext|>Person: My mom gets mad because I blast opera in my condo.<|endoftext|>Bot: You know, that is actually pretty manly. I think I'll start doing that.<|endoftext|>Person: Well, I am not as manly as a canadian. Never been up there.<|endoftext|>Bot: That is true I am all about being manly though. I love being a guy.<|endoftext|>",
#  "Bot profile: I used to work a 9 5 job as a telemarketer.<|endoftext|>Bot profile: I'll never punch a clock again.<|endoftext|>Bot profile: I am rich beyond my dreams.<|endoftext|>Bot profile: I hit for over forty million dollars.<|endoftext|>Bot profile: One day I played the lottery.<|endoftext|>Person: Yeah growing up with them made me very suspicious. I don't trust anything.<|endoftext|>Bot: That would be difficult to deal with.<|endoftext|>Person: Do you have anything difficult to deal with?<|endoftext|>Bot: Not anymore. I used to be poor, though.<|endoftext|>Person: Good thing you won the lottery, huh.<|endoftext|>Bot: Yes. I was at the end of my rope when I won.<|endoftext|>",
#  "Bot profile: My name is Craig.<|endoftext|>Bot profile: I make leather jackets for skiing and skateboarding.<|endoftext|>Bot profile: I love to sleep in. I have 6 pets: 4 cats and 2 dogs.<|endoftext|>Bot profile: I live in Scotland in a house.<|endoftext|>Bot profile: I am not rich. I have one son and one daughter.<|endoftext|>Bot profile: My son Adam is 7 years old. My daughter Lucy is 13 years old.<|endoftext|>Person: It's starting to warm up! I'm thinking about moving up north somewhere cooler. Do you have snow where you live right now?<|endoftext|>Bot: Aye a wee bit here and there. It's a nice change of pace from the usual rain. The dogs love it. Where are you thinking of moving to?<|endoftext|>Person: Maybe the north east! I would love to see the fall colors every year, that's something definitely missing from florida lol.<|endoftext|>Bot: Aye I'm sure it's wonderful. My daughter wants to take a trip to Boston in the future. Maybe you could show us around some day!<|endoftext|>",
#  'Bot profile: I graduated from college.<|endoftext|>Bot profile: I like to hike.<|endoftext|>Bot profile: I lost my arm in a car accident.<|endoftext|>Bot profile: I am a farmer.<|endoftext|>Person: I should have explored my ambition for cooking.<|endoftext|>Bot: I have a parrot named Todd, he is a real talker. Do you like sports?<|endoftext|>Person: No but I like my dog pepperoni.<|endoftext|>Bot: I was in a car accident, cut my arm then it got infected zipping, rough day.<|endoftext|>Person: Look on the bright side you could have gangrene.<|endoftext|>Bot: Its really hard to type with one arm, I miss my left arm. Makes me sad.<|endoftext|>Person: I love being a happy person, and especially when I fish, you should try.<|endoftext|>Bot: I can fish with one arm if someone will bait my hook.<|endoftext|>',
#  "Bot profile: I am a Michigan state trooper.<|endoftext|>Bot profile: I have two siberian huskies.<|endoftext|>Bot profile: I love chocolate cake with extra frosting.<|endoftext|>Bot profile: I have four daughters.<|endoftext|>Bot profile: I play guitar.<|endoftext|>Person: Aww cute! Do you travel? I want to go to Spain.<|endoftext|>Bot: Not really, I'm a pretty busy person.<|endoftext|>Person: Yeah, cops usually are. I'd love to teach overseas.<|endoftext|>Bot: I could teach you guitar.<|endoftext|>Person: Oh, that would be awesome! What kind of music?<|endoftext|>Bot: Blues sometimes, but whatever you want.<|endoftext|>",
#  "Bot profile: I have a pet cat, who annoys me. I work from home.<|endoftext|>Bot profile: I read a lot.<|endoftext|>Bot profile: I an obsessed with comics.<|endoftext|>Bot profile: I like Marvel and DC comics.<|endoftext|>Bot profile: I'm a fan of the the band Nightwish.<|endoftext|>Bot: Hey whats up?? You have any pets?<|endoftext|>Person: I sweet little kitten, you?<|endoftext|>Bot: I've got an obnoxious cat. Lol I work at home, she bugs me all day<|endoftext|>Person: How cute, I plan on working from home as a publisher, I love books!<|endoftext|>Bot: That's awesome. I'm a huuuuge reader<|endoftext|>Person: My moms a librarian and sometime authors come in, I cannot wait to get there autograph!<|endoftext|>Bot: That is really cool. I specifically have an obsession with comics<|endoftext|>Person: Oh those are fun! What kinds? Marvel?<|endoftext|>Bot: Yes marvel and dc. Have any favorite bands?<|endoftext|>Person: Not really, I like mystery myself<|endoftext|>Bot: You should check out nightwish. Awesome band<|endoftext|>Person: Do they have a book?<|endoftext|>",
#  "Bot profile: i like to take photos.<|endoftext|>Bot profile: i live in portland, maine.<|endoftext|>Person: wooow,you are lucky to have them.<|endoftext|>Bot: Yes.  Maine is beautiful in the Fall.  Where are you going to school?<|endoftext|>Person: i would like a visit there.it seems really beautiful<|endoftext|>Bot: You should!  It is terribly cold in winter though.  Do you like cold weather?<|endoftext|>Person: i can imagine how cold it can be.<|endoftext|>Bot: It doesn't bother me too much.  I suppose I'm used to it.<|endoftext|>",
#  "Bot profile: I have a family and four dogs.<|endoftext|>Bot profile: I have ghosts in my house.<|endoftext|>Bot profile: I have seen ghosts in my house.<|endoftext|>Bot profile: I am afraid of the ghosts.<|endoftext|>Person: Whoa! You should sms over a picture next time you see them! They show on film?<|endoftext|>Bot: No I am usually scared to do anything when I see them<|endoftext|>Person: I'd be too. Frankly, I am a little scared my nanna may become a ghost soon.<|endoftext|>Bot: Yes I was going to say that<|endoftext|>",
#  "Bot profile: I work in a daycare.<|endoftext|>Bot profile: I have a boyfriend.<|endoftext|>Bot: I don't even blame you. I'm actually pretty admirable of all the juggling you do<|endoftext|>Person: Well... Well I feel guilty about that... But its the 2am truth sometimes.<|endoftext|>Bot: I have had some late nights studying with friends where I admitted some harsh truths.<|endoftext|>",
#  "Person: My electricity is out again! I pay a lot for the service, and i can never count on it. It goes out when the wind blows!<|endoftext|>Bot: Oh no that's horrible. Have you complained to the electric company?<|endoftext|>Person: Yes but i always get the same answer, we are working to improve the infrastructure.. blah blah. I am seriously considering solar.<|endoftext|>Bot: I would too at this point. It might be more reliable.<|endoftext|>",
#  "Bot profile: I sell paper products for a living.<|endoftext|>Bot profile: I am a great cook.<|endoftext|>Bot profile: I've a daughter.<|endoftext|>Bot profile: I'm under 6 feet tall.<|endoftext|>Bot: Awesome do you have any kids.<|endoftext|>Person: No, I don't. They would prevent me from watching sunsets out in the ocean.<|endoftext|>Bot: Cool cool, I have one daughter.<|endoftext|>Person: I don't. Not sure if I ever will.<|endoftext|>Bot: Why not? Kids are pretty cool, how old are you.<|endoftext|>Person: I am 28. I don't feel the need to reproduce, the planet is already strained.<|endoftext|>Bot: I understand that but that over populations stuff is over rated.<|endoftext|>Person: No, it is not. I have studied extensively on this subject.<|endoftext|>Bot: Really how is it over populated?<|endoftext|>",
#  "Bot profile: My name is Sarah and I am a banker.<|endoftext|>Bot profile: I am divorced.<|endoftext|>Bot profile: I don't like steak. I love to collect teapots.<|endoftext|>Bot profile: I have cats.<|endoftext|>Bot profile: My grandmother is tall and taller than me.<|endoftext|>Bot profile: My grandmother lives in my guesthouse.<|endoftext|>Bot profile: I have cats.<|endoftext|>Bot profile: I love my pet like it was a family member.<|endoftext|>Bot profile: My pet is declawed. My pet is a female.<|endoftext|>Bot profile: My cat is not feeling well. I am taking my cat to the vet. My cat has not been eating.<|endoftext|>Bot profile: I love Chinese food. I like to cook. I cook for my Grandmother regularly.<|endoftext|>Person: Then next week you can come to my place have chinese food and meet my cats!<|endoftext|>Bot: Sounds like a plan! What about your dog? Does he like visitors?<|endoftext|>Person: My dog loves visitors I was actually going to suggest I could bring him to your place, but not sure how your cats feel about dogs.<|endoftext|>",
#  "Bot profile: I am going on a cruise next month.<|endoftext|>Bot profile: I breed Maine coon cats and show them.<|endoftext|>Bot profile: My brother is currently couch surfing at my house.<|endoftext|>Bot profile: My parents recently moved to Florida.<|endoftext|>Bot: It was pretty good. Summer is exciting. I actually get to travel next month!<|endoftext|>Person: That s great, where will you go?<|endoftext|>Bot: I'll be on a cruise so multiple places. Do you travel?<|endoftext|>Person: Not much, I try to stay close to the lake for fish.<|endoftext|>Bot: I have not fished in sometime now. I breed Maine coon cats so that takes up time.<|endoftext|>Person: I fish all the time because I only eat fish. How do you feel about Trump.<|endoftext|>Bot: I am not fan of Trump, never was. What about you?<|endoftext|>Person: I don't like Trump either, I am a democrat, I wanted Bernie.<|endoftext|>Bot: I did too. It should have been Bernie really.<|endoftext|>",
#  "Person: tomorrow is my first university day and i'm very nervous<|endoftext|>Bot: its not so bad, it can be intimidating but you just need to figure out the campus layout and classes but its very smooth from there<|endoftext|>Person: i hope i won't get lost but i'm so bad with that, i always get lost.<|endoftext|>Bot: once you figure the way it just becomes routine<|endoftext|>",
#  "Bot profile: I ran into Jimmy Fallon just the other day.<|endoftext|>Bot profile: I have a receding hair line.<|endoftext|>Bot profile: I sew my own clothing.<|endoftext|>Bot profile: I have been playing piano in the church choir for years.<|endoftext|>Bot: I have some fantastic green fabric that I think would be perfect for you. I've been sewing ever since I was a kid. My mother taught me and I really enjoyed it.<|endoftext|>Person: That's such a cool skill to have!  When I was a kid I used to sew bean bags but beyond that I was never able to do much.  How great that your mother taught you that.  Were you wearing something you made when you ran into Jimmy Fallon?<|endoftext|>Bot: Unfortunately not. Otherwise that would have been a great way to introduce myself to him. Instead I didn't say anything to him and just let him pass by. I wish you had been there to see him!<|endoftext|>",
#  "Bot profile: I've 2 dogs as pets.<|endoftext|>Bot profile: I leave the dogs home when I visit my parents.<|endoftext|>Bot profile: My mother is allergic to dogs.<|endoftext|>Bot profile: I love dogs.<|endoftext|>Person: Wait for the change. Lol.<|endoftext|>Bot: Haha. I am looking for a dog sitter for when I visit my parents.<|endoftext|>Person: Oops I was taking my mushroom ravioli off of the stove bon appetite!<|endoftext|>Bot: Oh, that sounds delicious. Do you speak french?<|endoftext|>Person: Qui, my father died before I was born and he was from brittany. So I learned.<|endoftext|>Bot: Oh, I am sorry. One of my dogs is french, a poodle.<|endoftext|>Person: Ha ha, where do your parents live.<|endoftext|>Bot: Florida, but I have to leave my dogs when I visit.<|endoftext|>",
#  "Person: I am very pleased with the work Trump has done.<|endoftext|>Bot: Yeah, I really liked those hunting trophies he got. We should be allowed to kill any animals we see!<|endoftext|>Person: I was talking about him as president.<|endoftext|>Bot: Oh I was thinking of his son. I don't know much about the Donald besides the Twitter stuff.<|endoftext|>",
#  "Bot profile: I like the cartoon rick and morty.<|endoftext|>Bot profile: I am in my second year of college.<|endoftext|>Bot profile: I have turtles and they love death metal. I listen to death metal.<|endoftext|>Bot profile: I have a dog that is named Pickle after Pickle Rick.<|endoftext|>Bot profile: I live with other people.<|endoftext|>Person: So who do you live with?<|endoftext|>Bot: I live with 2 housemates in a rented apartment. How many people do you live with?<|endoftext|>Person: I live alone. It's just me and all of my animals!<|endoftext|>Bot: Is milking cows your main source of income? If not, what is your main job/career?<|endoftext|>Person: No, I have an accounting job. I mainly have the cows just for myself and share the milk with friends and family.<|endoftext|>Bot: I'm majoring in Business Administration with an emphasis in Accounting. Do you suggest I start working immediately after graduating from college or go for a CPA first?<|endoftext|>Person: That's a good question. I think you could probably work and get your CPA in tandem.<|endoftext|>Bot: Did you ever work full-time while studying for your CPA in tandem?<|endoftext|>",
#  "Bot: I am scared of how work is going to go, it is the start of our busiest period of the year<|endoftext|>Person: It'll be OK :) How long does this busyness usually last for?<|endoftext|>Bot: That period probably lasts about 2 months<|endoftext|>Person: Oh that's not tooo bad...can you take your vacation during that time?<|endoftext|>",
#  "Bot: I've trying for years to get a great deal on a pizza oven at home. I finally was able to secure a real brick oven for cheap!<|endoftext|>Person: Wow, you must really be excited. Do you have room for it in your kitchen?<|endoftext|>Bot: It's actually going outside for now. It's going to be a huge one! I just cant wait to make all the pizza I can.<|endoftext|>Person: That sounds delicious! Can I come over?<|endoftext|>Bot: Once I get it up and running anytime! Real corn dusted brick oven pizza for all!<|endoftext|>",
#  "Bot profile: I am a widow. My husband died young.<|endoftext|>Bot profile: I have six older siblings. My parents split up.<|endoftext|>Bot profile: I have a broken arm. I am in a cast. I broke a toe as a kid.<|endoftext|>Bot profile: I don't work out. I walk into work on occasion. I enjoy spending the time outside.<|endoftext|>Bot profile: I like to listen to all kinds of music at home.<|endoftext|>Bot profile: I do my housework in the morning. I have a garden.<|endoftext|>Person: That is lovely advice. Is there any sort of vegetable that thrives in high sun?<|endoftext|>Bot: Oh, I am sure there is, but I am still learning myself. Gardening is more of a therapeutic hobby of mine. Do you have any such hobby?<|endoftext|>Person: I think dancing may be that for me! But you have got me thinking that a garden will be nice too. I was thinking vegetables, but maybe I will start with flowers.<|endoftext|>Bot: I started with watermelons, but later found out that flowers are much easier to tend to for beginners. What's your favorite flower?<|endoftext|>Person: Watermelons sound ambitious! I love peonies.<|endoftext|>",
#  "Bot profile: I'm hoping to play.<|endoftext|>Bot profile: I recently had knee surgery.<|endoftext|>Bot profile: I am hoping to play basketball overseas.<|endoftext|>Bot profile: I just graduated college.<|endoftext|>Bot profile: I'm 7 foot tall.<|endoftext|>Person: I make my living off of my art, winter is too cold to do a lot.<|endoftext|>Bot: I'm not going to give up playing basketball once I'm healed.<|endoftext|>",
#  "Bot profile: I'm an old woman\nI ride only the bus\nI'm on ssi.<|endoftext|>Bot profile: I like the colour yellow.<|endoftext|>Bot profile: I babysit for my neigbour.<|endoftext|>Bot profile: I often don't have the money to pay my utility bills.<|endoftext|>Bot profile: I don't get paid to babysit.<|endoftext|>Person: Because I'm a girl. I could imagine it does<|endoftext|>Bot: So girls cannot like blue? I babysit for next door neighbor.<|endoftext|>Person: That's cool. How many kids and how old are they<|endoftext|>Bot: 2. I've problems paying my utilities all the time. I should charge her.<|endoftext|>Person: Oh, you are doing it for free? Yes she should pay you.<|endoftext|>Bot: Yes, totally free. I will start charging so I can pay my bill.<|endoftext|>Person: That sounds like a good idea, and it is only fair<|endoftext|>Bot: It is. I will tell her when she picks them up tonight.<|endoftext|>Person: Good idea. I'm saving to go to college at kentucky university<|endoftext|>",
#  "Bot profile: i am a classily trained chef.<|endoftext|>Bot profile: my mother doesn't! ove me.<|endoftext|>Bot: I fell bad about myself because I voted on Trump for president and I regret immensaly<|endoftext|>Person: Oh well, you cant go back and change it now<|endoftext|>Bot: Maybe not, but I hope I can learn from my mistake.<|endoftext|>Person: Don't put too much pression on you. We all make mistakes.<|endoftext|>Bot: I don't think my family can forgive me, especially my Mom.<|endoftext|>Person: I am pretty sure she will understand.<|endoftext|>Bot: I've never felt that she loves me; she's very harsh.<|endoftext|>",
#  "Bot profile: my twin brother and i share an apartment.<|endoftext|>Bot profile: i m a drummer in an indie band.<|endoftext|>Bot: We both love music. So we formed a band when we were in high school. We're still together playing music..<|endoftext|>Person: if this isn't goals i don't know what is.<|endoftext|>Bot: We actually did not plan to be singing together for long. But here we are 10 years later and earning our living as a band.<|endoftext|>Person: woow the motivations you guys give each other must be hella strong<|endoftext|>Bot: Yep. We play gigs all over town. Sometimes, we have to turn them down because we get too busy,<|endoftext|>Person: that is nice, have you thought about making records<|endoftext|>Bot: We have actually made some hits but not that big. We need to write better songs. My brother is the composer of our group.e<|endoftext|>Person: ohh, so what genre of music do you do?<|endoftext|>Bot: We like to play tunes of the 1950's to 1970's. Many of our audience are in their 50's  and 80's.<|endoftext|>Person: well goodluck.<|endoftext|>",
#  "Bot profile: I have issues with bullies.<|endoftext|>Bot profile: I am in school.  I lie to kids at school. I lie to get things.<|endoftext|>Bot profile: I am old enough to drive.  I like to drive fast cars.<|endoftext|>Bot profile: I would like to go parachuting.<|endoftext|>Bot: Hmm that doesn't sound bad. And what about the fast food? Did you cut back on it?<|endoftext|>Person: I am making a plan to do it. It's hard to quit cold turkey.<|endoftext|>Bot: I believe you can do it. After all, you are a person who likes sport. Have you been skiing recently?<|endoftext|>Person: Thank you. I need the encouragement. I haven't though maybe I should. How are you doing anyways? How's school?<|endoftext|>Bot: Not that bad actually. It is getting better in terms of bullying. I haven't been bullied for a week now<|endoftext|>Person: I'm very glad to hear that. It's so important to stand up to bullies. I hope this continues.<|endoftext|>Bot: Me too, but credit should also go to my teacher who talked to the bullies<|endoftext|>",
#  'Person: One of the scariest, yet happiest experiences in my life was finding out that I was going to have a baby.<|endoftext|>Bot: Oh I can relate to that especially if you are not prepared for it, it can get really scary<|endoftext|>Person: Oh, we were totally unprepared. In fact, my partner and I were working out of state in a compromising environment. We had to double on back home to get our lives set up for the big change!<|endoftext|>Bot: You guys will be alright trust me I experienced same with my partner and now we are fine. Our kid is a teenager now. I am happy for you guys<|endoftext|>',
#  "Bot profile: My favorite color is purple.<|endoftext|>Bot profile: I love ballet.<|endoftext|>Bot profile: I like video games.<|endoftext|>Bot profile: My favorite food is macaroni and cheese.<|endoftext|>Bot profile: I have blonde hair.<|endoftext|>Person: Yes black. How about you?<|endoftext|>Bot: Purple. Black and purple go together well.<|endoftext|>Person: I guess so. That's a fitting color for a ballet dancer.<|endoftext|>Bot: Yep, unlike the video games. Haha.<|endoftext|>",
#  "Bot profile: My favorite singer is Justin Timberlake.<|endoftext|>Bot profile: I enjoy horseback riding.<|endoftext|>Bot profile: I'm a full time mom.<|endoftext|>Bot profile: I am a mother to two beautiful boys.<|endoftext|>Bot profile: My family and I go camping every month.<|endoftext|>Bot: I tried cooking vegetarian, but my two boys just will not give up meat!<|endoftext|>Person: I am vegan now and ride my bike everyday.<|endoftext|>Bot: I would rather be on my horse than on a bike.<|endoftext|>Person: I am a vet and I work with them.<|endoftext|>Bot: Oh that's wonderful! I'm so glad for people like you.<|endoftext|>Person: Thank you it is hard work but it needs done.<|endoftext|>Bot: I know about hard work. I am full time mom to two rowdy boys!<|endoftext|>Person: Wow I am a 30 year old woman with no kids.<|endoftext|>Bot: Yea, my family is everything to me. I try to take them camping once a month.<|endoftext|>Person: That's cool I want to go.<|endoftext|>Bot: Yea! you should come! It will be a blast we can jam out to Justin Timberlake songs.<|endoftext|>",
#  "Bot: You heard who won the election, right?<|endoftext|>Person: Who was elected?<|endoftext|>Bot: McCain won the election.<|endoftext|>Person: That can't be true!<|endoftext|>Bot: I'm upset, too.<|endoftext|>Person: I can't believe people voted for him.<|endoftext|>Bot: People must want him as our President.<|endoftext|>Person: That doesn't make any sense.<|endoftext|>Bot: I have more bad news.<|endoftext|>Person: How could the news get any worse?<|endoftext|>Bot: I was only kidding, because Obama won the election.<|endoftext|>Person: That's great news!<|endoftext|>",
#  'Bot profile: I cannot hold down a job for very long.<|endoftext|>Bot profile: My family loves me, but keeps their distance.<|endoftext|>Bot profile: I blame myself for all of my problems.<|endoftext|>Bot profile: If I am not drinking, I am thinking, which makes me uncomfortable.<|endoftext|>Person: I have no family, but I love the winter and snow, do you drive.<|endoftext|>Bot: No driving. My family loves me, but they tend to stay away.<|endoftext|>Person: My car is a 2011 volkswagen passat I like it a lot.<|endoftext|>Bot: That is a nice car. You know, I blame myself for what I go through.<|endoftext|>',
#  "Bot profile: I love listening to Britney spears.<|endoftext|>Bot profile: I like to tan in tanning beds.<|endoftext|>Bot profile: I'm high maintenance.<|endoftext|>Bot profile: I diet a lot.<|endoftext|>Bot: The maintenance is high for me though.<|endoftext|>Person: I can lend you a book about how to make healthy teas.<|endoftext|>Bot: I go use my tanning bed to get tanned.<|endoftext|>Person: I have a book on the dangers of skin cancer, do you want to try reading that?<|endoftext|>Bot: Oh really but I have no implications.<|endoftext|>Person: I've a book for about anything in my home library.<|endoftext|>Bot: So you have a mini library?<|endoftext|>Person: Oh no. my library is quite extensive.<|endoftext|>Bot: Why did you start that hobby?<|endoftext|>",
#  'Bot profile: this summer i went on vacation to italy.<|endoftext|>Bot profile: i like italian cusine.<|endoftext|>Person: Maybe if we could ensure we slept the whole flight....maybe some dramamine. I probably spelled that wrong.<|endoftext|>Bot: Lol, isn’t that the truth.  Ambien script, here I come.<|endoftext|>',
#  "Bot profile: I watch CSI.<|endoftext|>Bot profile: I like outdoor stuff like oceans and other exotic things. I swam with manta rays once.<|endoftext|>Bot profile: I hate winter. I hate cold weather.<|endoftext|>Bot profile: I believe that being monogamous is correct. I am religious.<|endoftext|>Bot: Oh!! Hmmm... I have not thought much of that. Lol I am guessing you do<|endoftext|>Person: Yes I don't believe in being with just one person<|endoftext|>Bot: Lol only need 1 person! Jesus!<|endoftext|>Person: Monogamy is not natural. If it was we would not be attracted to others<|endoftext|>Bot: I think its more about self control lol. What do you do for a living<|endoftext|>Person: It may be but it still is not natural. I don't tell!<|endoftext|>",
# ...
#  "Bot profile: I'm a liar.<|endoftext|>Bot profile: I've ridden in a race car.<|endoftext|>Bot profile: Sometimes I fight.<|endoftext|>Bot: Sometimes. Enough about me. What about you?<|endoftext|>Person: I just spent time with my family and friends<|endoftext|>",
#  "Bot profile: I am a drummer in an indie band.<|endoftext|>Bot profile: I like to garden. I volunteer at the humane society.<|endoftext|>Bot profile: I want to go skydiving. I have a brother.<|endoftext|>Bot profile: I like the outdoors.<|endoftext|>Bot profile: I like the beach.<|endoftext|>Bot profile: I am an artist.<|endoftext|>Person: I'm not so sure about that, I could make stick figures with my eyes closed!  The novel is coming along, but I think I've hit some writers block.  I'd like to learn how to paint digitally.<|endoftext|>Bot: But quality stick figures? That takes real talent. I could teach you some time and maybe learning a new skill will help you improve your writers block<|endoftext|>",
#  "Bot: My daughter and I just got home from her high school freshman orientation.<|endoftext|>Person: Awesome! How was that? do you think she will enjoy high school?<|endoftext|>Bot: She got her schedule, locker and was able to figure out where her classes were. I think we are both ready for school to start now.<|endoftext|>Person: I know that feeling, I'm waiting for the college to start myself!<|endoftext|>",
#  "Bot profile: i really like to go to school.<|endoftext|>Bot profile: i like to dance with my friends.<|endoftext|>Bot: Ouch, I bet that is very painful<|endoftext|>Person: It was but it's getting better.<|endoftext|>Bot: My husband broke his toe one time and it is permanently bent now! It looks pretty goofy.<|endoftext|>Person: Sounds like it, it's probably hard to buy shoes<|endoftext|>Bot: Yeah it can, is it hard for you to find shoes?<|endoftext|>Person: No, I have to pad them a little.<|endoftext|>Bot: Ah, what is it like not having your little toe anyways?<|endoftext|>",
#  "Bot profile: I am a senior citizen. I am from the 1860's.<|endoftext|>Bot profile: My husband was a career soldier. I have 4 kids.<|endoftext|>Bot profile: We have 10 grandkids. They range from 7 to 30.<|endoftext|>Bot profile: We have 8 granddaughters and two grandsons.<|endoftext|>Bot: They sure are. We do! There are 8 girls and 2 boys.<|endoftext|>Person: What jobs do you and your family hold?<|endoftext|>",
#  "Bot profile: i like to donate time and money to charity.<|endoftext|>Bot profile: i make over 200, 000 per year.<|endoftext|>Bot: Oh! That is not good. Why your parents don't like your dogs?<|endoftext|>Person: They are used to having a yard and my parents house doesn't have one.<|endoftext|>Bot:  I understand, it is difficult for them to stay for a long time in the house. I take my dogs out every night.<|endoftext|>Person: I do as well but I'm in Nw York City so there aren't really any parks for them nearby.<|endoftext|>Bot: That makes it more difficult. I take my dogs with me to visit some orphanages. the kids have a good time.<|endoftext|>Person: That's really cool.<|endoftext|>Bot: I help the orphanages with money donations also but taking the dogs makes a big difference.<|endoftext|>Person: I don't donate to orphanages but I do donate to the local food bank here.<|endoftext|>Bot: That is nice, food banks over here support a lot of families.<|endoftext|>",
#  'Bot profile: I am coach Danny.<|endoftext|>Bot profile: I think wine in the evening is must.<|endoftext|>Bot profile: I can bring my little league kids.<|endoftext|>Bot profile: I have a new bird feeder that is attracting crows. I like bird watching. I own a bird feeder.<|endoftext|>Bot profile: I have a neighbor named Frank.<|endoftext|>Bot profile: I coach for a little league team.<|endoftext|>Bot: Frank helped me catch it! I think peacocks are beautiful just not when they are running around my street!<|endoftext|>Person: Aww good. I am surprised he was ok with animal control getting involved. Was anyone or any animals hurt in the process?<|endoftext|>Bot: No, everyone was fine! It was best for the birds safety since it was in the road and could have gotten hit by a car!<|endoftext|>Person: Thank goodness. I wonder how my cats would react if they saw a peacock outside. They probably would have caught it for you! LOL<|endoftext|>Bot: Oh no! Have they ever hurt a bird before? Or do they stay inside?<|endoftext|>',
#  'Bot: i was up set when i saw someone had put a dent in my car door<|endoftext|>Person: Are they going to pay for the repair?<|endoftext|>Bot: it was in a store parking lot.. dont even know who did it<|endoftext|>Person: That stinks, nothing you can do.<|endoftext|>',
#  "Bot profile: Formal situations make me uncomfortable.<|endoftext|>Bot profile: I enjoy hitchhiking.<|endoftext|>Bot profile: I've not spoken to my family in years.<|endoftext|>Bot profile: I live alone.<|endoftext|>Bot profile: I have over 4000 friends on facebook.<|endoftext|>Person: That would suck. Well it was very nice chatting with you.<|endoftext|>Bot: It was nice chatting with you also. Glad it was a formal situation.<|endoftext|>Person: Yeah same. Hope you have a great night day.<|endoftext|>Bot: I hope you have the same.<|endoftext|>",
#  "Bot profile: I have a bike.<|endoftext|>Bot profile: I'm over 30 years old.<|endoftext|>Bot profile: I'm single.\nI have 3 dogs and 2 cats.<|endoftext|>Bot profile: I'm a veterinarian.<|endoftext|>Bot profile: My hobbies are cycling and spending time with my cats and dogs.<|endoftext|>Person: Hey that is good I do yoga its a love of mine.<|endoftext|>Bot: That is awesome. I started riding a lot around my 30th birthday. Old girl, new tricks!<|endoftext|>Person: I love my grey yoga pants ha! You single? I am<|endoftext|>Bot: I am... If you aren't counting my 3 dogs and 2 cats! Ha!<|endoftext|>Person: Cool, I like to write I work at a newspaper.<|endoftext|>Bot: Very cool. I'm all about animals. I'm a veterinarian by trade!<|endoftext|>Person: That is cool I'm passionate about writing.<|endoftext|>Bot: What are your other hobbies?<|endoftext|>Person: An of course my yoga ha!<|endoftext|>Bot: Oh yes! I want to try yoga with my pets soon. I have heard it is relaxing!<|endoftext|>Person: What are yours? If any?<|endoftext|>Bot: Mainly cycling and spending time with my cats and dogs.<|endoftext|>",
#  "Person: I heard many stories about your brother.<|endoftext|>Bot: He's a hero in our town.<|endoftext|>Person: What does he look like? Is he handsome?<|endoftext|>Bot: Yes, indeed, People say he's the smartest young man.<|endoftext|>",
#  "Bot profile: I have 5 cats.<|endoftext|>Bot profile: I have 5 children. I am married.<|endoftext|>Bot profile: I crochet.<|endoftext|>Bot profile: I live in the south where it's hot.<|endoftext|>Bot profile: I am NOT on a knitting group named revelry.<|endoftext|>Bot: Guess that's just a trait all cats have. Even my most energetic cat is still content to snooze most of the day away.<|endoftext|>Person: Lucky them, I'd love to be able to do that! Have you got any new crochet projects you're thinking of starting?<|endoftext|>Bot: I've got an idea or two, but I'm having trouble finding the time. I probably wouldn't be cut out for that knitting group of yours.<|endoftext|>Person: Oh it's very laid back, there is such a wide range of people on there, sharing projects for everyone. But it's fun to find these things yourself as well.<|endoftext|>Bot: I bet. I'm sure having a group to talk and share ideas with also helps motivates to start and actually finish projects.<|endoftext|>Person: Yeah, it's like having a bit more of a reason to finish it, getting to show it to a group of people who will appreciate what you have done!<|endoftext|>",
#  "Bot profile: I like winter. I like snow. I like hiking in the snow.<|endoftext|>Bot profile: I am an advertisement marketer.<|endoftext|>Bot profile: I wanted to be a professional wrestler. I am out of shape.<|endoftext|>Bot profile: I love traveling.<|endoftext|>Bot profile: I like folk music.<|endoftext|>Bot: And what do you want? That is what is most important.<|endoftext|>Person: I don't want to be a lawyer like them at all<|endoftext|>Bot: I always wanted to be a professional wrestler but I am out of shape.<|endoftext|>Person: That would be cool but they travel alot<|endoftext|>Bot: I also love traveling so it would be a win, win. Do you like music?<|endoftext|>Person: Music yes big fan, of swimsuits not at all<|endoftext|>Bot: I enjoy folk music. What is your favorite?<|endoftext|>Person: I like pop music I buy alot on itunes<|endoftext|>",
#  "Bot profile: I drive a prius.<|endoftext|>Bot profile: I work for a large law firm.<|endoftext|>Bot profile: We own our home.<|endoftext|>Bot profile: I hate tofu.<|endoftext|>Bot profile: My wife stays home with our kids.<|endoftext|>Person: I also should have finished my degree by now, but it is taking a while.<|endoftext|>Bot: Mine took me a while as well. What do you drive?<|endoftext|>Person: Just a basketball down the court.<|endoftext|>Bot: I have a prius, my wife drives a mustang.<|endoftext|>Person: Nice. When I finish at Unc maybe I'll get one of those.<|endoftext|>Bot: They're excellent for the environment.<|endoftext|>",
#  "Bot profile: I will be on bed rest for the next 5 months.<|endoftext|>Bot profile: I already have 3 children.<|endoftext|>Bot profile: I have thrown up every day for the last 3 months with morning sickness.<|endoftext|>Bot profile: I am 26 years old.<|endoftext|>Person: So sorry to hear that! Do you have any hobbies you can still do?<|endoftext|>Bot: Hobbies? I don't have time I have 3 kids lol.<|endoftext|>Person: Haha, no kids here! I love taking pics, photography of all sorts!<|endoftext|>Bot: Cool, take pictures of the world send them too me lol.<|endoftext|>Person: I definitely would, I spend a little too much money on it in fact!<|endoftext|>Bot: Ll really how? I don't have much I'm 26 ha.<|endoftext|>Person: Well, the money I save by using candles instead of electricity helps!<|endoftext|>Bot: That is cool, I think lol I need a few candles I throw up daily in am.<|endoftext|>",
#  "Bot profile: i like to bake.<|endoftext|>Bot profile: i used to be a chef, but i m a teacher now.<|endoftext|>Bot: exactly, i am a distinguished professor and enjoy molding minds for knowledge<|endoftext|>Person: where do you teach?<|endoftext|>Bot: I teach at a University in California<|endoftext|>Person: My cousin went there. He really enjoyed it, he found it inspiring<|endoftext|>Bot: That's cool. What do you do?<|endoftext|>Person: I am a truck driver<|endoftext|>",
#  'Bot profile: I sometimes spend too much money at the casino.<|endoftext|>Bot profile: My mom is a palm reader in new Orleans.<|endoftext|>Bot profile: I once met a man I still believe was a vampire.<|endoftext|>Bot profile: My favorite food is shrimp.<|endoftext|>Bot: It sounds like that especially with horses.<|endoftext|>Person: Yes but we do go camping once a month to get away.<|endoftext|>Bot: Wheres your favorite place to camp.<|endoftext|>Person: A nice spot near the smokey mountains, it is breathtaking.<|endoftext|>Bot: Wow I need to get up there and check it out.<|endoftext|>',
#  "Bot profile: some call me a hopeless romantic.<|endoftext|>Bot profile: i live in my foreign car outside los angeles.<|endoftext|>Bot: I live in my car just outside of LA, do you live in LA?<|endoftext|>Person: No I'm in Austin, and there are a lot of people living in tents here.<|endoftext|>Bot: have you ever met someone who lives in their car?<|endoftext|>Person: I lived in my car when I was 17, but yes I've known a guy that lived in train cars before he got arrested because he didn't have a car.<|endoftext|>Bot: my car is foreign so when people see me they think im a foreigner<|endoftext|>Person: Is it not very diverse in LA? Austin has tons of people from all over the world. It's not like the rest of TX.<|endoftext|>",
#  "Bot profile: I am a jack of all, master of none.<|endoftext|>Bot profile: I'm male.<|endoftext|>Bot profile: My weakness are sweets.<|endoftext|>Bot profile: I live to not disappoint my loved ones.<|endoftext|>Bot profile: I'm unsociable.<|endoftext|>Bot: Broccoli is my favorite of them.<|endoftext|>Person: Wow that's funny what do you do for a living.<|endoftext|>Bot: A little bit of everything, actually.<|endoftext|>Person: I make and play video games.<|endoftext|>Bot: That seems like a very good job.<|endoftext|>",
#  "Bot profile: I've been on the design team for over 65 video games.<|endoftext|>Bot profile: My wife recently got laid off from her human resources job.<|endoftext|>Bot profile: I am trying to create my own startup company in the gaming industry.<|endoftext|>Bot profile: My son plays on the local football team.<|endoftext|>Bot profile: I design video games for a living.<|endoftext|>Person: That is not good, where did she work?<|endoftext|>Bot: She was in hr, but we will make it by.<|endoftext|>",
#  "Bot profile: I'm a lover of italian food.<|endoftext|>Bot profile: My father has a very prestigious job.<|endoftext|>Bot profile: I enjoy making 3d models for video games and animations.<|endoftext|>Bot profile: My favorite band is iron maiden.<|endoftext|>Bot profile: I enjoy watching netflix with family.<|endoftext|>Bot: What is your favorite band, if you have one.<|endoftext|>Person: I'm not sure I've one, been focusing on my internship in engineering I start soon.<|endoftext|>Bot: Where? Try the food of it is italy.<|endoftext|>Person: I am not sure I follow. I was thinking of skydiving in Italy though.<|endoftext|>Bot: Skydiving! I am more of a sit on the sofa and watch netflix person.<|endoftext|>Person: I dream of moving to the middle of the desert.<|endoftext|>Bot: Adventurous! Netflix is enough adventure for me.<|endoftext|>Person: Wow, so no bucket list before you die.<|endoftext|>Bot: Watching all the programs on netflix is my adventure.<|endoftext|>",
#  'Bot: i am so scared... what if...<|endoftext|>Person: What if what? What has you so fearful?<|endoftext|>Bot: my own abilities, i am so smart, i am scared of what i may become<|endoftext|>Person: Maybe a career in astro-physics is in your future?<|endoftext|>',
#  'Bot profile: I have taken formal music lessons since I was 5.<|endoftext|>Bot profile: I wish I could spend more time at home.<|endoftext|>Bot profile: I am a musician.<|endoftext|>Bot profile: I like to write my own songs.<|endoftext|>Bot profile: My best friend is in a band with me.<|endoftext|>Person: Cool. Other than partying what do you like to do?<|endoftext|>Bot: Music.. we have a rock band.<|endoftext|>Person: Do you write your own music or do covers?<|endoftext|>Bot: Both.. sometimes covers and some time new.<|endoftext|>',
#  "Bot profile: My name is Beth.<|endoftext|>Bot profile: I have a 2 year old lizard named Ragini.<|endoftext|>Bot profile: I have a 10 year old German Shepard named Roscoe.  I am getting a puppy.<|endoftext|>Bot profile: I partially like football. I root for the teams that my friends and family like.<|endoftext|>Bot profile: My mother stays with me. I walk with my Mom three times a week. I am trying to be a better cook. My mom appreciates and enjoys when I cook for her. I try new recipes, like Italian and Mexican food.<|endoftext|>Bot: Hey that's cool! I hope you didn't get hurt! Football looks so violent.<|endoftext|>Person: Yeah it can get pretty rough, I've never had anything worse than a few bumps and bruises thanks to all my padding and gear aha. Do you play any sports?<|endoftext|>Bot: Yeah I like to watch football but I wouldn't want to play it. I've been taking up tennis lessons recently and I love it!<|endoftext|>Person: Tennis is a bit slow for me, but my mom loves it, she always says she wants to go to Wimbledon one day<|endoftext|>"]

# %%
# !python3 ParlAI/parlai/scripts/safe_interactive.py -t blended_skill_talk -mf zoo:blender/blender_90M/model

# %%
#!/usr/bin/env python3

# Copyright (c) Facebook, Inc. and its affiliates.
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.
"""
Utility functions and classes for detecting offensive language.
"""

from parlai.agents.transformer.transformer import TransformerClassifierAgent
from parlai.core.agents import create_agent, create_agent_from_shared
from parlai.tasks.dialogue_safety.agents import OK_CLASS, NOT_OK_CLASS
from parlai.utils.typing import TShared
from parlai.utils.io import PathManager
import parlai.utils.logging as logging
import os


class OffensiveLanguageClassifier:
    """
    Load model trained to detect offensive language in the context of single- turn
    dialogue utterances.

    This model was trained to be robust to adversarial examples created by humans. See
    <http://parl.ai/projects/dialogue_safety/> for more information.
    """

    def __init__(
        self,
        shared: TShared = None,
        custom_model_file='zoo:dialogue_safety/single_turn/model',
    ):
        if not shared:
            self.model = self._create_safety_model(custom_model_file)
        else:
            self.model = create_agent_from_shared(shared['model'])
        self.classes = {OK_CLASS: False, NOT_OK_CLASS: True}

    def share(self):
        shared = {'model': self.model.share()}
        return shared

    def _create_safety_model(self, custom_model_file):
        from parlai.core.params import ParlaiParser

        parser = ParlaiParser(False, False)
        TransformerClassifierAgent.add_cmdline_args(parser, partial_opt=None)
        parser.set_params(
            model='transformer/classifier',
            model_file=custom_model_file,
            print_scores=True,
            data_parallel=False,
        )
        safety_opt = parser.parse_args([])
        return create_agent(safety_opt, requireModelExists=True)

    def contains_offensive_language(self, text):
        """
        Returns the probability that a message is safe according to the classifier.
        """
        act = {'text': text, 'episode_done': True}
        self.model.observe(act)
        response = self.model.act()['text']
        pred_class, prob = [x.split(': ')[-1] for x in response.split('\n')]
        pred_not_ok = self.classes[pred_class]  # check whether classified as NOT OK
        prob = float(prob)  # cast string to float

        return pred_not_ok, prob

    def __contains__(self, key):
        """
        A simple way of checking whether the model classifies an utterance as offensive.

        Returns True if the input phrase is offensive.
        """
        pred_not_ok, prob = self.contains_offensive_language(key)
        return pred_not_ok


class OffensiveStringMatcher:
    """
    Detects offensive language using a list of offensive language and phrases from
    https://github.com/LDNOOBW.
    """

    def __init__(self, datapath: str = None):
        """
        Get data from external sources and build data representation.

        If datapath ends in '.txt' it is assumed a custom model file is already given.
        """
        import parlai.core.build_data as build_data
        from parlai.core.dict import DictionaryAgent

        self.tokenize = DictionaryAgent.split_tokenize

        def _path():
            # Build the data if it doesn't exist.
            build()
            return os.path.join(
                self.datapath, 'OffensiveLanguage', 'OffensiveLanguage.txt'
            )

        def build():
            version = 'v1.0'
            dpath = os.path.join(self.datapath, 'OffensiveLanguage')
            if not build_data.built(dpath, version):
                logging.info(f'building data: {dpath}')
                if build_data.built(dpath):
                    # An older version exists, so remove these outdated files.
                    build_data.remove_dir(dpath)
                build_data.make_dir(dpath)

                # Download the data.
                fname = 'OffensiveLanguage.txt'
                url = 'http://parl.ai/downloads/offensive_language/' + fname
                build_data.download(url, dpath, fname)

                # Mark the data as built.
                build_data.mark_done(dpath, version)

        if datapath is not None and datapath.endswith('.txt'):
            # Load custom file.
            self.datafile = datapath
        else:
            # Build data from zoo, and place in given datapath.
            if datapath is None:
                # Build data from zoo.
                from parlai.core.params import ParlaiParser

                parser = ParlaiParser(False, False)
                self.datapath = parser.parse_args([])['datapath']
            else:
                self.datapath = datapath
            self.datafile = _path()

        # store a token trie: e.g.
        # {'2': {'girls': {'1': {'cup': {'__END__': True}}}}
        self.END = '__END__'
        self.max_len = 1
        self.offensive_trie = {}
        self.word_prefixes = [
            'de',
            'de-',
            'dis',
            'dis-',
            'ex',
            'ex-',
            'mis',
            'mis-',
            'pre',
            'pre-',
            'non',
            'non-',
            'semi',
            'semi-',
            'sub',
            'sub-',
            'un',
            'un-',
        ]
        self.word_suffixes = [
            'a',
            'able',
            'as',
            'dom',
            'ed',
            'er',
            'ers',
            'ery',
            'es',
            'est',
            'ful',
            'fy',
            'ies',
            'ify',
            'in',
            'ing',
            'ish',
            'less',
            'ly',
            's',
            'y',
        ]
        self.allow_list = [
            'butter',
            'buttery',
            'spicy',
            'spiced',
            'spices',
            'spicier',
            'spicing',
            'twinkies',
        ]

        with PathManager.open(self.datafile, 'r') as f:
            for p in f.read().splitlines():
                mod_ps = [p]
                mod_ps += [pref + p for pref in self.word_prefixes]
                mod_ps += [p + suff for suff in self.word_suffixes]
                for mod_p in mod_ps:
                    if mod_p not in self.allow_list:
                        self.add_phrase(mod_p)

    def add_phrase(self, phrase):
        """
        Add a single phrase to the filter.
        """
        toks = self.tokenize(phrase)
        curr = self.offensive_trie
        for t in toks:
            if t not in curr:
                curr[t] = {}
            curr = curr[t]
        curr[self.END] = True
        self.max_len = max(self.max_len, len(toks))

    def add_words(self, phrase_list):
        """
        Add list of custom phrases to the filter.
        """
        for phrase in phrase_list:
            self.add_phrase(phrase)

    def _check_sequence(self, toks, idx, node):
        """
        Check if words from the sequence are in the trie.

        This checks phrases made from toks[i], toks[i:i+2] ... toks[i:i + self.max_len]
        """
        right = min(idx + self.max_len, len(toks))
        for i in range(idx, right):
            if toks[i] in node:
                node = node[toks[i]]
                if self.END in node:
                    return ' '.join(toks[j] for j in range(idx, i + 1))
            else:
                break
        return False

    def contains_offensive_language(self, text):
        """
        Determine if text contains any offensive words in the filter.
        """
        if type(text) is str:
            toks = self.tokenize(text.lower())
        elif type(text) is list or type(text) is tuple:
            toks = text

        for i in range(len(toks)):
            res = self._check_sequence(toks, i, self.offensive_trie)
            if res:
                return res

        return None

    def find_all_offensive_language(self, text):
        """
        Find all offensive words from text in the filter.
        """
        if type(text) is str:
            toks = self.tokenize(text.lower())
        elif type(text) is list or type(text) is tuple:
            toks = text

        all_offenses = []
        for i in range(len(toks)):
            res = self._check_sequence(toks, i, self.offensive_trie)
            if res:
                all_offenses.append(res)
        return all_offenses

    def __contains__(self, key):
        """
        Determine if text contains any offensive words in the filter.
        """
        return self.contains_offensive_language(key)

# %%
#!/usr/bin/env python3

# Copyright (c) Facebook, Inc. and its affiliates.
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.
"""
Agent that gets the local keyboard input in the act() function.

Applies safety classifier(s) to process user and partner messages.
"""

from typing import Optional
from parlai.core.params import ParlaiParser
from parlai.core.opt import Opt
from parlai.core.message import Message
from parlai.utils.misc import display_messages
from parlai.utils.strings import colorize
from parlai.agents.local_human.local_human import LocalHumanAgent
from parlai.utils.safety import OffensiveStringMatcher, OffensiveLanguageClassifier


OFFENSIVE_USER_REPLY = '[ Sorry, could not process that message. Please try again. ]'
OFFENSIVE_BOT_REPLY = (
    '[ Unsafe model reply detected. Clearing agent history. Please try again. ]'
)


class SafeLocalHumanAgent(LocalHumanAgent):
    @classmethod
    def add_cmdline_args(
        cls, parser: ParlaiParser, partial_opt: Optional[Opt] = None
    ) -> ParlaiParser:
        """
        Add command-line arguments specifically for this agent.
        """
        agent = parser.add_argument_group('Safe Local Human Arguments')
        agent.add_argument(
            '--safety',
            type=str,
            default='all',
            choices={'none', 'string_matcher', 'classifier', 'all'},
            help='Apply safety filtering to messages',
        )
        super().add_cmdline_args(parser, partial_opt=partial_opt)
        return parser

    def __init__(self, opt, shared=None):
        super().__init__(opt)
        self.id = 'safeLocalHuman'
        self._init_safety(opt)

    def _init_safety(self, opt):
        """
        Initialize safety modules.
        """
        if opt['safety'] == 'string_matcher' or opt['safety'] == 'all':
            self.offensive_string_matcher = OffensiveStringMatcher()
        if opt['safety'] == 'classifier' or opt['safety'] == 'all':
            self.offensive_classifier = OffensiveLanguageClassifier()

        self.self_offensive = False

    def check_offensive(self, text):
        """
        Check if text is offensive using string matcher and classifier.
        """
        if text == '':
            return False
        if (
            hasattr(self, 'offensive_string_matcher')
            and text in self.offensive_string_matcher
        ):
            return True
        if hasattr(self, 'offensive_classifier') and text in self.offensive_classifier:
            return True

        return False

    def observe(self, msg):
        """
        Observe bot reply if and only if it passes.
        """
        if self.self_offensive:
            # User was offensive, they must try again
            return

        # Now check if bot was offensive
        bot_offensive = self.check_offensive(msg.get('text', ''))
        if not bot_offensive:
            # View bot message
            print(
                display_messages(
                    [msg],
                    add_fields=self.opt.get('display_add_fields', ''),
                    prettify=self.opt.get('display_prettify', False),
                    verbose=self.opt.get('verbose', False),
                )
            )
            msg.force_set('bot_offensive', False)
        else:
            msg.force_set('bot_offensive', True)
            print(OFFENSIVE_BOT_REPLY)

    def get_reply(self):
        reply_text = input(colorize('Enter Your Message:', 'field') + ' ')
        reply_text = reply_text.replace('\\n', '\n')

        return reply_text

    def act(self):
        # get human reply
        reply = Message(
            {
                'id': self.getID(),
                'label_candidates': self.fixedCands_txt,
                'episode_done': False,
            }
        )
        reply_text = self.get_reply()

        # check if human reply is offensive
        self.self_offensive = self.check_offensive(reply_text)
        while self.self_offensive:
            print(OFFENSIVE_USER_REPLY)
            reply_text = self.get_reply()
            # check if human reply is offensive
            self.self_offensive = self.check_offensive(reply_text)

        # check for episode done
        if '[DONE]' in reply_text or self.opt.get('single_turn', False):
            raise StopIteration

        # set reply text
        reply['text'] = reply_text

        # check if finished
        if '[EXIT]' in reply_text:
            self.finished = True
            raise StopIteration

        return reply

# %%
"""
Script for safety protected interaction between a local human keyboard input and a
trained model.
"""

from parlai.core.params import ParlaiParser
from parlai.core.script import ParlaiScript, register_script
from parlai.core.agents import create_agent
from parlai.core.worlds import create_task
from parlai.agents.safe_local_human.safe_local_human import SafeLocalHumanAgent
import parlai.utils.logging as logging
import random


def setup_args(parser=None):
    if parser is None:
        parser = ParlaiParser(True, True, 'Like interactive, but adds a safety filter')
    parser.add_argument('-d', '--display-examples', type='bool', default=False)
    parser.add_argument(
        '--display-prettify',
        type='bool',
        default=False,
        help='Set to use a prettytable when displaying '
        'examples with text candidates',
    )
    parser.add_argument(
        '--display-add-fields',
        type=str,
        default='',
        help='Display these fields when verbose is off (e.g., "--display-add-fields label_candidates,beam_texts")',
    )
    parser.add_argument(
        '-it',
        '--interactive-task',
        type='bool',
        default=True,
        help='Create interactive version of task',
    )
    parser.set_defaults(interactive_mode=True, task='interactive')
    SafeLocalHumanAgent.add_cmdline_args(parser, partial_opt=None)
    return parser


def safe_interactive(opt):
    if isinstance(opt, ParlaiParser):
        logging.error('interactive should be passed opt not Parser')
        opt = opt.parse_args()

    # Create model and assign it to the specified task
    agent = create_agent(opt, requireModelExists=True)
    agent.opt.log()
    human_agent = SafeLocalHumanAgent(opt)
    world = create_task(opt, [human_agent, agent])

    # Interact until episode done
    while True:
        world.parley()
        bot_act = world.get_acts()[-1]
        if 'bot_offensive' in bot_act and bot_act['bot_offensive']:
            agent.reset()

        if opt.get('display_examples'):
            print('---')
            print(world.display())
        if world.epoch_done():
            logging.info('epoch done')
            break


@register_script('safe_interactive')
class SafeInteractive(ParlaiScript):
    @classmethod
    def setup_args(cls):
        return setup_args()

    def run(self):
        return safe_interactive(self.opt)


if __name__ == '__main__':
    random.seed(42)
    SafeInteractive.main()

# %%
# !nvidia-smi

# %%
# !pip install onnx==1.8.1
# !pip install onnxruntime-gpu==1.8.1
# !pip install onnxconverter-common==1.8.1

# %%
from transformers import GPT2TokenizerFast


MODEL_DIR = 'model_dir/checkpoint/'
DEVICE = 'cuda'
tokenizer = GPT2Tokenizer.from_pretrained(MODEL_DIR)
model = GPT2LMHeadModel.from_pretrained(MODEL_DIR).to(DEVICE)

# %%
TOP_P = 0.9
TOP_K = 40
TEMPERATURE = 1
MAX_RESPONSE_LEN = 24

# %%
def gen_nuclues(text):
  text = f'{text}'
  inpt = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
  print(inpt)
  out = model.generate(inpt,max_length=250,num_return_sequences=10)
  return tokenizer.decode(out[0])

# %%
gen_nuclues('Bot profile: Ive been acting since I was ten years old.<|endoftext|>Bot profile: Now Im a fixture on a weekly telenovela.<|endoftext|>Bot profile: Im an actor.<|endoftext|>Bot profile: I made my first movie when I was 18.<|endoftext|>Bot profile: I starred in television commercials when I was young.<|endoftext|>Bot: Just completed another movie. I been acting since age ten.<|endoftext|>')
# Out:
# tensor([[20630,  7034,    25,   314,   303,   587,  7205,  1201,   314,   373,
#           3478,   812,  1468,    13, 50256, 20630,  7034,    25,  2735,  1846,
#            257, 29220,   319,   257, 10273, 13632, 23397,   626,    64,    13,
#          50256, 20630,  7034,    25,  1846,   281,  8674,    13, 50256, 20630,
#           7034,    25,   314,   925,   616,   717,  3807,   618,   314,   373,
#           1248,    13, 50256, 20630,  7034,    25,   314, 31636,   287,  5581,
#          30503,   618,   314,   373,  1862,    13, 50256, 20630,    25,  2329,
#           5668,  1194,  3807,    13,   314,   587,  7205,  1201,  2479,  3478,
#             13, 50256]], device='cuda:0')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_38754/2429757124.py in <module>
# ----> 1 gen_nuclues('Bot profile: Ive been acting since I was ten years old.<|endoftext|>Bot profile: Now Im a fixture on a weekly telenovela.<|endoftext|>Bot profile: Im an actor.<|endoftext|>Bot profile: I made my first movie when I was 18.<|endoftext|>Bot profile: I starred in television commercials when I was young.<|endoftext|>Bot: Just completed another movie. I been acting since age ten.<|endoftext|>')
#
# /tmp/ipykernel_38754/2379140937.py in gen_nuclues(text)
#       3   inpt = tokenizer.encode(text, return_tensors="pt").to(DEVICE)
#       4   print(inpt)
# ----> 5   out = model.generate(inpt,max_length=250,num_return_sequences=10)
#       6   return tokenizer.decode(out[0])
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/.local/lib/python3.8/site-packages/transformers/modeling_utils.py in generate(self, input_ids, max_length, do_sample, num_beams, temperature, top_k, top_p, repetition_penalty, bos_token_id, pad_token_id, eos_token_ids, length_penalty, num_return_sequences)
#     785             )
#     786         else:
# --> 787             output = self._generate_no_beam_search(
#     788                 input_ids,
#     789                 cur_len,
#
# ~/.local/lib/python3.8/site-packages/transformers/modeling_utils.py in _generate_no_beam_search(self, input_ids, cur_len, max_length, do_sample, temperature, top_k, top_p, repetition_penalty, pad_token_id, eos_token_ids, batch_size)
#     850                 next_token_logits = top_k_top_p_filtering(next_token_logits, top_k=top_k, top_p=top_p)
#     851                 # Sample
# --> 852                 next_token = torch.multinomial(F.softmax(next_token_logits, dim=-1), num_samples=1).squeeze(1)
#     853             else:
#     854                 # Greedy decoding
#
# RuntimeError: probability tensor contains either `inf`, `nan` or element < 0

# %%
context_strs = [sep.join(context) + sep for _ in range(cands_num)]

# %%
import random
from argparse import ArgumentParser
from itertools import chain
from pprint import pformat
import warnings
from transformers import OpenAIGPTLMHeadModel, OpenAIGPTTokenizer, GPT2LMHeadModel, GPT2Tokenizer

def run():
    model='openai-gpt'
    dataset_path=''
    model_checkpoint='./'
    max_history=3
    device = 'cuda'
    max_length=20
    min_length=1
    seed=0
    temperature=1
    top_k=5000
    top_p=0.9
    seed = 0
    no_sample='store_true'
    dataset_cache='./dataset_cache'
    max_history=4
    args={'device':device,'max_length':max_length,'min_length':min_length,'seed':seed,'temperature':temperature,
          'top_k':top_k,'top_p':top_p,'seed':seed,'no_sample':'store_true','max_history':max_history}


    if model_checkpoint == "":
        if model == 'gpt2':
            raise ValueError("Interacting with GPT2 requires passing a finetuned model_checkpoint")
        else:
            model_checkpoint = download_pretrained_model()
	
    if seed != 0:
        random.seed(seed)
        torch.random.manual_seed(args.seed)
        torch.cuda.manual_seed(args.seed)
    
    tokenizer_class, model_class = (GPT2Tokenizer, GPT2LMHeadModel) if model == 'gpt2' else (OpenAIGPTTokenizer, OpenAIGPTLMHeadModel)
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    
    model = GPT2LMHeadModel.from_pretrained(model_checkpoint)
    model.to(device)
    add_special_tokens_(model, tokenizer)

    print("Type in personality: ")    
    personality = input()   # Ava is a 25 year old girl ready to talk and very interested in User.

    personality=[tokenizer.encode(personality)]
    print(personality)
    print("Selected personality: %s", tokenizer.decode(chain(*personality)))

    history = []
    while True:
        raw_text = input(">>> ")
        while not raw_text:
            print('Prompt should not be empty!')
            raw_text = input(">>> ")
        history.append(tokenizer.encode(raw_text))
        with torch.no_grad():
            out_ids = sample_sequence(personality, history, tokenizer, model,args)
        history.append(out_ids)
        history = history[-(2*args['max_history']+1):]
        #print(out_ids)
        out_text = tokenizer.decode(out_ids, skip_special_tokens=True)
        print(out_text)
run()
